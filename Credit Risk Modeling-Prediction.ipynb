# %%
# Import necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score
from scipy.stats import chi2_contingency
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, precision_recall_fscore_support
import warnings
import os
import time

# %%
# !pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting scikit-learn
#   Using cached scikit_learn-1.7.1-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\debarka\appdata\roaming\python\python312\site-packages (from scikit-learn) (2.2.6)
# Collecting scipy>=1.8.0 (from scikit-learn)
#   Downloading scipy-1.16.1-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Downloading joblib-1.5.2-py3-none-any.whl.metadata (5.6 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Using cached scikit_learn-1.7.1-cp312-cp312-win_amd64.whl (8.7 MB)
# Downloading joblib-1.5.2-py3-none-any.whl (308 kB)
# Downloading scipy-1.16.1-cp312-cp312-win_amd64.whl (38.5 MB)
#    ---------------------------------------- 0.0/38.5 MB ? eta -:--:--
#    -- ------------------------------------- 2.4/38.5 MB 13.4 MB/s eta 0:00:03
#    ---- ----------------------------------- 4.7/38.5 MB 12.4 MB/s eta 0:00:03
#    ------- -------------------------------- 7.1/38.5 MB 12.1 MB/s eta 0:00:03
#    ---------- ----------------------------- 9.7/38.5 MB 12.1 MB/s eta 0:00:03
#    ------------ --------------------------- 12.3/38.5 MB 12.1 MB/s eta 0:00:03
#    --------------- ------------------------ 14.7/38.5 MB 12.0 MB/s eta 0:00:02
#    ----------------- ---------------------- 17.0/38.5 MB 11.9 MB/s eta 0:00:02
#    -------------------- ------------------- 19.7/38.5 MB 11.9 MB/s eta 0:00:02
#    ---------------------- ----------------- 22.0/38.5 MB 11.9 MB/s eta 0:00:02
#    ------------------------- -------------- 24.4/38.5 MB 11.9 MB/s eta 0:00:02
#    ---------------------------- ----------- 27.0/38.5 MB 11.9 MB/s eta 0:00:01
#    ------------------------------ --------- 29.4/38.5 MB 11.9 MB/s eta 0:00:01
#    --------------------------------- ------ 32.0/38.5 MB 11.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 34.3/38.5 MB 11.9 MB/s eta 0:00:01
#    -------------------------------------- - 36.7/38.5 MB 11.9 MB/s eta 0:00:01
#    ---------------------------------------  38.3/38.5 MB 11.9 MB/s eta 0:00:01
#    ---------------------------------------  38.3/38.5 MB 11.9 MB/s eta 0:00:01
#    ---------------------------------------  38.3/38.5 MB 11.9 MB/s eta 0:00:01
#    ---------------------------------------  38.3/38.5 MB 11.9 MB/s eta 0:00:01
#    ---------------------------------------  38.3/38.5 MB 11.9 MB/s eta 0:00:01
#    ---------------------------------------  38.3/38.5 MB 11.9 MB/s eta 0:00:01
#    ---------------------------------------  38.3/38.5 MB 11.9 MB/s eta 0:00:01
#    ---------------------------------------  38.3/38.5 MB 11.9 MB/s eta 0:00:01
#    ---------------------------------------  38.3/38.5 MB 11.9 MB/s eta 0:00:01
#    ---------------------------------------  38.3/38.5 MB 11.9 MB/s eta 0:00:01
#    ---------------------------------------- 38.5/38.5 MB 7.3 MB/s eta 0:00:00
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
#
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    -------------------- ------------------- 2/4 [joblib]
#    -------------------- ------------------- 2/4 [joblib]
#    -------------------- ------------------- 2/4 [joblib]
#    -------------------- ------------------- 2/4 [joblib]
#    -------------------- ------------------- 2/4 [joblib]
#    -------------------- ------------------- 2/4 [joblib]
#    -------------------- ------------------- 2/4 [joblib]
#    -------------------- ------------------- 2/4 [joblib]
#    -------------------- ------------------- 2/4 [joblib]
#    -------------------- ------------------- 2/4 [joblib]
#    -------------------- ------------------- 2/4 [joblib]
#    -------------------- ------------------- 2/4 [joblib]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ---------------------------------------- 4/4 [scikit-learn]
#
# Successfully installed joblib-1.5.2 scikit-learn-1.7.1 scipy-1.16.1 threadpoolctl-3.6.0
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install statsmodels
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting statsmodels
#   Using cached statsmodels-0.14.5-cp312-cp312-win_amd64.whl.metadata (9.8 kB)
# Requirement already satisfied: numpy<3,>=1.22.3 in c:\users\debarka\appdata\roaming\python\python312\site-packages (from statsmodels) (2.2.6)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in c:\users\debarka\appdata\roaming\python\python312\site-packages (from statsmodels) (1.16.1)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in c:\users\debarka\appdata\roaming\python\python312\site-packages (from statsmodels) (2.2.3)
# Collecting patsy>=0.5.6 (from statsmodels)
#   Using cached patsy-1.0.1-py2.py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: packaging>=21.3 in c:\users\debarka\appdata\roaming\python\python312\site-packages (from statsmodels) (24.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\debarka\appdata\roaming\python\python312\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\debarka\appdata\roaming\python\python312\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\debarka\appdata\roaming\python\python312\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2024.2)
# Requirement already satisfied: six>=1.5 in c:\users\debarka\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,>=1.4->statsmodels) (1.16.0)
# Using cached statsmodels-0.14.5-cp312-cp312-win_amd64.whl (9.6 MB)
# Using cached patsy-1.0.1-py2.py3-none-any.whl (232 kB)
# Installing collected packages: patsy, statsmodels
#
#    ---------------------------------------- 0/2 [patsy]
#    ---------------------------------------- 0/2 [patsy]
#    ---------------------------------------- 0/2 [patsy]
#    ---------------------------------------- 0/2 [patsy]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    ---------------------------------------- 2/2 [statsmodels]
#
# Successfully installed patsy-1.0.1 statsmodels-0.14.5
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Load the dataset
a1 = pd.read_excel("Data/Internal_Bank_Dataset.xlsx")
a2 = pd.read_excel("Data/External_Cibil_Dataset.xlsx")

# %%
# !pip install openpyxl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting openpyxl
#   Using cached openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting et-xmlfile (from openpyxl)
#   Using cached et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Using cached openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Using cached et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Installing collected packages: et-xmlfile, openpyxl
#
#    ---------------------------------------- 0/2 [et-xmlfile]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    ---------------------------------------- 2/2 [openpyxl]
#
# Successfully installed et-xmlfile-2.0.0 openpyxl-3.1.5
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
df1 = a1.copy()
df2 = a2.copy()

# %%
df1
# Out:
#        PROSPECTID  Total_TL  Tot_Closed_TL  Tot_Active_TL  \
# 0               1         5              4              1
# 1               2         1              0              1
# 2               3         8              0              8
# 3               4         1              0              1
# 4               5         3              2              1
# ...           ...       ...            ...            ...
# 51331       51332         3              0              3
# 51332       51333         4              2              2
# 51333       51334         2              1              1
# 51334       51335         2              1              1
# 51335       51336         1              0              1
#
#        Total_TL_opened_L6M  Tot_TL_closed_L6M  pct_tl_open_L6M  \
# 0                        0                  0            0.000
# 1                        0                  0            0.000
# 2                        1                  0            0.125
# 3                        1                  0            1.000
# 4                        0                  0            0.000
# ...                    ...                ...              ...
# 51331                    1                  0            0.333
# 51332                    0                  1            0.000
# 51333                    1                  1            0.500
# 51334                    0                  0            0.000
# 51335                    0                  0            0.000
#
#        pct_tl_closed_L6M  pct_active_tl  pct_closed_tl  ...  CC_TL  \
# 0                   0.00          0.200          0.800  ...      0
# 1                   0.00          1.000          0.000  ...      0
# 2                   0.00          1.000          0.000  ...      0
# 3                   0.00          1.000          0.000  ...      0
# 4                   0.00          0.333          0.667  ...      0
# ...                  ...            ...            ...  ...    ...
# 51331               0.00          1.000          0.000  ...      0
# 51332               0.25          0.500          0.500  ...      0
# 51333               0.50          0.500          0.500  ...      0
# 51334               0.00          0.500          0.500  ...      0
# 51335               0.00          1.000          0.000  ...      0
#
#        Consumer_TL  Gold_TL  Home_TL  PL_TL  Secured_TL  Unsecured_TL  \
# 0                0        1        0      4           1             4
# 1                1        0        0      0           0             1
# 2                6        1        0      0           2             6
# 3                0        0        0      0           0             1
# 4                0        0        0      0           3             0
# ...            ...      ...      ...    ...         ...           ...
# 51331            2        0        0      0           0             3
# 51332            2        0        0      0           2             2
# 51333            2        0        0      0           0             2
# 51334            2        0        0      0           0             2
# 51335            0        0        0      0           1             0
#
#        Other_TL  Age_Oldest_TL  Age_Newest_TL
# 0             0             72             18
# 1             0              7              7
# 2             0             47              2
# 3             1              5              5
# 4             2            131             32
# ...         ...            ...            ...
# 51331         1             24              5
# 51332         0             74              7
# 51333         0              9              5
# 51334         0             15              8
# 51335         0             20             20
#
# [51336 rows x 26 columns]

# %%
# Remove nulls
df1 = df1.loc[df1['Age_Oldest_TL'] != -99999]

# %%
columns_to_be_removed = []

for i in df2.columns:
    if df2.loc[df2[i] == -99999].shape[0] > 10000:
        columns_to_be_removed .append(i)

# %%
df2 = df2.drop(columns_to_be_removed, axis =1)
print(f"We have dropped {columns_to_be_removed}")
# Out:
# We have dropped ['time_since_first_deliquency', 'time_since_recent_deliquency', 'max_delinquency_level', 'max_deliq_6mts', 'max_deliq_12mts', 'CC_utilization', 'PL_utilization', 'max_unsec_exposure_inPct']

# %%
for i in df2.columns:
    df2 = df2.loc[ df2[i] != -99999 ]

# %%
# Checking common column names
for i in list(df1.columns):
    if i in list(df2.columns):
        print (i)
# Out:
# PROSPECTID

# %%
# Merge the two dataframes, inner join so that no nulls are present
df = pd. merge ( df1, df2, how ='inner', left_on = ['PROSPECTID'], right_on = ['PROSPECTID'] )

# %%
# check how many columns are categorical
for i in df.columns:
    if df[i].dtype == 'object':
        print(i)
# Out:
# MARITALSTATUS
# EDUCATION
# GENDER
# last_prod_enq2
# first_prod_enq2
# Approved_Flag

# %%
# Chi-square test
for i in ['MARITALSTATUS', 'EDUCATION', 'GENDER', 'last_prod_enq2', 'first_prod_enq2']:
    chi2, pval, _, _ = chi2_contingency(pd.crosstab(df[i], df['Approved_Flag']))
    print(i, '---', pval)
# Out:
# MARITALSTATUS --- 3.578180861038862e-233
# EDUCATION --- 2.6942265249737532e-30
# GENDER --- 1.907936100186563e-05
# last_prod_enq2 --- 0.0
# first_prod_enq2 --- 7.84997610555419e-287

# %% [markdown]
# ## Since all the categorical features have pval <=0.05, we will accept all

# %%
# VIF for numerical columns
numeric_columns = []
for i in df.columns:
    if df[i].dtype != 'object' and i not in ['PROSPECTID','Approved_Flag']:
        numeric_columns.append(i)

# %%
# VIF sequentially check

vif_data = df[numeric_columns]
total_columns = vif_data.shape[1]
columns_to_be_kept = []
column_index = 0

# %%
for i in range (0,total_columns):
    
    vif_value = variance_inflation_factor(vif_data, column_index)
    print (column_index,'---',vif_value)
    
    
    if vif_value <= 6:
        columns_to_be_kept.append( numeric_columns[i] )
        column_index = column_index+1
    
    else:
        vif_data = vif_data.drop([ numeric_columns[i] ] , axis=1)
# Out:
# C:\Users\DEBARKA\AppData\Roaming\Python\Python312\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# 0 --- inf
# C:\Users\DEBARKA\AppData\Roaming\Python\Python312\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# 0 --- inf
# 0 --- 11.320180023967996
# 0 --- 8.363698035000336
# 0 --- 6.520647877790928
# 0 --- 5.149501618212625
# 1 --- 2.611111040579735
# C:\Users\DEBARKA\AppData\Roaming\Python\Python312\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# 2 --- inf
# 2 --- 1788.7926256209232
# 2 --- 8.601028256477228
# 2 --- 3.8328007921530785
# 3 --- 6.0996533816467355
# 3 --- 5.581352009642762
# 4 --- 1.985584353098778
# C:\Users\DEBARKA\AppData\Roaming\Python\Python312\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# 5 --- inf
# 5 --- 4.809538302819343
# 6 --- 23.270628983464636
# 6 --- 30.595522588100053
# 6 --- 4.3843464059655854
# 7 --- 3.0646584155234238
# 8 --- 2.898639771299252
# 9 --- 4.377876915347322
# 10 --- 2.2078535836958433
# 11 --- 4.916914200506864
# 12 --- 5.214702030064725
# 13 --- 3.3861625024231476
# 14 --- 7.840583309478997
# 14 --- 5.255034641721438
# C:\Users\DEBARKA\AppData\Roaming\Python\Python312\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# 15 --- inf
# 15 --- 7.380634506427232
# 15 --- 1.421005001517573
# 16 --- 8.083255010190316
# 16 --- 1.6241227524040114
# 17 --- 7.257811920140003
# 17 --- 15.59624383268298
# 17 --- 1.825857047132431
# 18 --- 1.5080839450032666
# 19 --- 2.172088834824578
# 20 --- 2.623397553527229
# 21 --- 2.2959970812106167
# 22 --- 7.360578319196446
# 22 --- 2.1602387773102554
# 23 --- 2.8686288267891467
# 24 --- 6.458218003637272
# 24 --- 2.8474118865638265
# 25 --- 4.7531981562840855
# 26 --- 16.22735475594825
# 26 --- 6.424377256363877
# 26 --- 8.887080381808687
# 26 --- 2.3804746142952653
# 27 --- 8.60951347651454
# 27 --- 13.06755093547673
# 27 --- 3.5000400566546555
# 28 --- 1.9087955874813773
# 29 --- 17.006562234161628
# 29 --- 10.730485153719197
# 29 --- 2.3538497522950275
# 30 --- 22.104855915136433
# 30 --- 2.7971639638512915
# 31 --- 3.424171203217696
# 32 --- 10.175021454450935
# 32 --- 6.408710354561301
# 32 --- 1.0011511962625612
# 33 --- 3.069197305397274
# 34 --- 2.8091261600643724
# 35 --- 20.249538381980678
# 35 --- 15.864576541593774
# 35 --- 1.8331649740532163
# 36 --- 1.5680839909542035
# 37 --- 1.9307572353811677
# 38 --- 4.331265056645247
# 39 --- 9.390334396150173

# %%
# check Anova for columns_to_be_kept 

from scipy.stats import f_oneway

columns_to_be_kept_numerical = []

for i in columns_to_be_kept:
    a = list(df[i])  
    b = list(df['Approved_Flag'])  
    
    group_P1 = [value for value, group in zip(a, b) if group == 'P1']
    group_P2 = [value for value, group in zip(a, b) if group == 'P2']
    group_P3 = [value for value, group in zip(a, b) if group == 'P3']
    group_P4 = [value for value, group in zip(a, b) if group == 'P4']


    f_statistic, p_value = f_oneway(group_P1, group_P2, group_P3, group_P4)

    if p_value <= 0.05:
        columns_to_be_kept_numerical.append(i)

# %%
# feature selection is done for cat and num features
# listing all the final features
features = columns_to_be_kept_numerical + ['MARITALSTATUS', 'EDUCATION', 'GENDER', 'last_prod_enq2', 'first_prod_enq2']
df = df[features + ['Approved_Flag']]

# %%
# Label encoding for the categorical features
['MARITALSTATUS', 'EDUCATION', 'GENDER' , 'last_prod_enq2' ,'first_prod_enq2']



df['MARITALSTATUS'].unique()    
df['EDUCATION'].unique()
df['GENDER'].unique()
df['last_prod_enq2'].unique()
df['first_prod_enq2'].unique()
# Out:
# array(['PL', 'ConsumerLoan', 'others', 'AL', 'HL', 'CC'], dtype=object)

# %%
# Ordinal feature -- EDUCATION
# SSC            : 1
# 12TH           : 2
# GRADUATE       : 3
# UNDER GRADUATE : 3
# POST-GRADUATE  : 4
# OTHERS         : 1
# PROFESSIONAL   : 3

# Others has to be verified by the business end user 


df.loc[df['EDUCATION'] == 'SSC',['EDUCATION']]              = 1
df.loc[df['EDUCATION'] == '12TH',['EDUCATION']]             = 2
df.loc[df['EDUCATION'] == 'GRADUATE',['EDUCATION']]         = 3
df.loc[df['EDUCATION'] == 'UNDER GRADUATE',['EDUCATION']]   = 3
df.loc[df['EDUCATION'] == 'POST-GRADUATE',['EDUCATION']]    = 4
df.loc[df['EDUCATION'] == 'OTHERS',['EDUCATION']]           = 1
df.loc[df['EDUCATION'] == 'PROFESSIONAL',['EDUCATION']]     = 3

# %%
df['EDUCATION'] = df['EDUCATION'].astype(int)

# %%
df_encoded = pd.get_dummies(df, columns=['MARITALSTATUS','GENDER', 'last_prod_enq2' ,'first_prod_enq2'])



df_encoded.info()
k = df_encoded.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42064 entries, 0 to 42063
# Data columns (total 55 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   pct_tl_open_L6M               42064 non-null  float64
#  1   pct_tl_closed_L6M             42064 non-null  float64
#  2   Tot_TL_closed_L12M            42064 non-null  int64
#  3   pct_tl_closed_L12M            42064 non-null  float64
#  4   Tot_Missed_Pmnt               42064 non-null  int64
#  5   CC_TL                         42064 non-null  int64
#  6   Home_TL                       42064 non-null  int64
#  7   PL_TL                         42064 non-null  int64
#  8   Secured_TL                    42064 non-null  int64
#  9   Unsecured_TL                  42064 non-null  int64
#  10  Other_TL                      42064 non-null  int64
#  11  Age_Oldest_TL                 42064 non-null  int64
#  12  Age_Newest_TL                 42064 non-null  int64
#  13  time_since_recent_payment     42064 non-null  int64
#  14  max_recent_level_of_deliq     42064 non-null  int64
#  15  num_deliq_6_12mts             42064 non-null  int64
#  16  num_times_60p_dpd             42064 non-null  int64
#  17  num_std_12mts                 42064 non-null  int64
#  18  num_sub                       42064 non-null  int64
#  19  num_sub_6mts                  42064 non-null  int64
#  20  num_sub_12mts                 42064 non-null  int64
#  21  num_dbt                       42064 non-null  int64
#  22  num_dbt_12mts                 42064 non-null  int64
#  23  num_lss                       42064 non-null  int64
#  24  recent_level_of_deliq         42064 non-null  int64
#  25  CC_enq_L12m                   42064 non-null  int64
#  26  PL_enq_L12m                   42064 non-null  int64
#  27  time_since_recent_enq         42064 non-null  int64
#  28  enq_L3m                       42064 non-null  int64
#  29  NETMONTHLYINCOME              42064 non-null  int64
#  30  Time_With_Curr_Empr           42064 non-null  int64
#  31  CC_Flag                       42064 non-null  int64
#  32  PL_Flag                       42064 non-null  int64
#  33  pct_PL_enq_L6m_of_ever        42064 non-null  float64
#  34  pct_CC_enq_L6m_of_ever        42064 non-null  float64
#  35  HL_Flag                       42064 non-null  int64
#  36  GL_Flag                       42064 non-null  int64
#  37  EDUCATION                     42064 non-null  int64
#  38  Approved_Flag                 42064 non-null  object
#  39  MARITALSTATUS_Married         42064 non-null  bool
#  40  MARITALSTATUS_Single          42064 non-null  bool
#  41  GENDER_F                      42064 non-null  bool
#  42  GENDER_M                      42064 non-null  bool
#  43  last_prod_enq2_AL             42064 non-null  bool
#  44  last_prod_enq2_CC             42064 non-null  bool
#  45  last_prod_enq2_ConsumerLoan   42064 non-null  bool
#  46  last_prod_enq2_HL             42064 non-null  bool
#  47  last_prod_enq2_PL             42064 non-null  bool
#  48  last_prod_enq2_others         42064 non-null  bool
#  49  first_prod_enq2_AL            42064 non-null  bool
#  50  first_prod_enq2_CC            42064 non-null  bool
#  51  first_prod_enq2_ConsumerLoan  42064 non-null  bool
#  52  first_prod_enq2_HL            42064 non-null  bool
#  53  first_prod_enq2_PL            42064 non-null  bool
#  54  first_prod_enq2_others        42064 non-null  bool
# dtypes: bool(16), float64(5), int64(33), object(1)
# memory usage: 13.2+ MB

# %% [markdown]
# # Machine Learning model fitting
# ## Data processing

# %%
#Random Forest
y = df_encoded['Approved_Flag']
x = df_encoded. drop ( ['Approved_Flag'], axis = 1 )

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
rf_classifier = RandomForestClassifier(n_estimators = 200, random_state=42)
rf_classifier.fit(x_train, y_train)
y_pred = rf_classifier.predict(x_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
print ()
print(f'Accuracy: {accuracy}')
print ()
precision, recall, f1_score, _ = precision_recall_fscore_support(y_test, y_pred)


for i, v in enumerate(['p1', 'p2', 'p3', 'p4']):
    print(f"Class {v}:")
    print(f"Precision: {precision[i]}")
    print(f"Recall: {recall[i]}")
    print(f"F1 Score: {f1_score[i]}")
    print()
# Out:
# Accuracy: 0.7636990372043266
#
# Class p1:
# Precision: 0.8370457209847597
# Recall: 0.7041420118343196
# F1 Score: 0.7648634172469202
#
# Class p2:
# Precision: 0.7957519116397621
# Recall: 0.9282457879088206
# F1 Score: 0.856907593778591
#
# Class p3:
# Precision: 0.4423380726698262
# Recall: 0.21132075471698114
# F1 Score: 0.28600612870275793
#
# Class p4:
# Precision: 0.7178502879078695
# Recall: 0.7269193391642371
# F1 Score: 0.7223563495895703

# %%
pip install xgboost
# Out:
# Note: you may need to restart the kernel to use updated packages.Defaulting to user installation because normal site-packages is not writeable
# Collecting xgboost
#   Downloading xgboost-3.0.5-py3-none-win_amd64.whl.metadata (2.1 kB)
# Requirement already satisfied: numpy in c:\users\debarka\appdata\roaming\python\python312\site-packages (from xgboost) (2.2.6)
# Requirement already satisfied: scipy in c:\users\debarka\appdata\roaming\python\python312\site-packages (from xgboost) (1.16.1)
# Downloading xgboost-3.0.5-py3-none-win_amd64.whl (56.8 MB)
#    ---------------------------------------- 0.0/56.8 MB ? eta -:--:--
#    - -------------------------------------- 2.4/56.8 MB 12.2 MB/s eta 0:00:05
#    --- ------------------------------------ 4.7/56.8 MB 11.9 MB/s eta 0:00:05
#    ----- ---------------------------------- 7.3/56.8 MB 11.9 MB/s eta 0:00:05
#    ------ --------------------------------- 9.7/56.8 MB 11.8 MB/s eta 0:00:04
#    -------- ------------------------------- 12.1/56.8 MB 11.8 MB/s eta 0:00:04
#    ---------- ----------------------------- 14.7/56.8 MB 11.8 MB/s eta 0:00:04
#    ----------- ---------------------------- 17.0/56.8 MB 11.8 MB/s eta 0:00:04
#    ------------- -------------------------- 19.4/56.8 MB 11.9 MB/s eta 0:00:04
#    --------------- ------------------------ 21.8/56.8 MB 11.9 MB/s eta 0:00:03
#    ----------------- ---------------------- 24.4/56.8 MB 11.9 MB/s eta 0:00:03
#    ------------------ --------------------- 26.7/56.8 MB 11.9 MB/s eta 0:00:03
#    -------------------- ------------------- 29.1/56.8 MB 11.8 MB/s eta 0:00:03
#    ---------------------- ----------------- 31.7/56.8 MB 11.8 MB/s eta 0:00:03
#    ----------------------- ---------------- 34.1/56.8 MB 11.8 MB/s eta 0:00:02
#    ------------------------- -------------- 36.4/56.8 MB 11.8 MB/s eta 0:00:02
#    --------------------------- ------------ 38.8/56.8 MB 11.8 MB/s eta 0:00:02
#    ---------------------------- ----------- 41.2/56.8 MB 11.8 MB/s eta 0:00:02
#    ------------------------------ --------- 43.5/56.8 MB 11.8 MB/s eta 0:00:02
#    -------------------------------- ------- 46.1/56.8 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 48.5/56.8 MB 11.8 MB/s eta 0:00:01
#    ----------------------------------- ---- 50.9/56.8 MB 11.8 MB/s eta 0:00:01
#    ------------------------------------- -- 53.2/56.8 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------  56.1/56.8 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------  56.6/56.8 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------  56.6/56.8 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------  56.6/56.8 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------  56.6/56.8 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------  56.6/56.8 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------  56.6/56.8 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------  56.6/56.8 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------  56.6/56.8 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------  56.6/56.8 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------  56.6/56.8 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------  56.6/56.8 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------  56.6/56.8 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------  56.6/56.8 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------- 56.8/56.8 MB 7.5 MB/s eta 0:00:00
# Installing collected packages: xgboost
# Successfully installed xgboost-3.0.5
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import xgboost as xgb
from sklearn.preprocessing import LabelEncoder

xgb_classifier = xgb.XGBClassifier(objective='multi:softmax',  num_class=4)

# %%
y = df_encoded['Approved_Flag']
x = df_encoded. drop ( ['Approved_Flag'], axis = 1 )

# %%
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y_encoded, test_size=0.2, random_state=42)

# %%
xgb_classifier.fit(x_train, y_train)
y_pred = xgb_classifier.predict(x_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
print ()
print(f'Accuracy: {accuracy:.2f}')
print ()

precision, recall, f1_score, _ = precision_recall_fscore_support(y_test, y_pred)

for i, v in enumerate(['p1', 'p2', 'p3', 'p4']):
    print(f"Class {v}:")
    print(f"Precision: {precision[i]}")
    print(f"Recall: {recall[i]}")
    print(f"F1 Score: {f1_score[i]}")
    print()
# Out:
# Accuracy: 0.78
#
# Class p1:
# Precision: 0.823906083244397
# Recall: 0.7613412228796844
# F1 Score: 0.7913890312660175
#
# Class p2:
# Precision: 0.8255418233924413
# Recall: 0.913577799801784
# F1 Score: 0.8673315769665035
#
# Class p3:
# Precision: 0.4756380510440835
# Recall: 0.30943396226415093
# F1 Score: 0.37494284407864653
#
# Class p4:
# Precision: 0.7342386032977691
# Recall: 0.7356656948493683
# F1 Score: 0.7349514563106796

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
y = df_encoded['Approved_Flag']
x = df_encoded. drop ( ['Approved_Flag'], axis = 1 )

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
dt_model = DecisionTreeClassifier(max_depth=20, min_samples_split=10)
dt_model.fit(x_train, y_train)
y_pred = dt_model.predict(x_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
print ()
print(f"Accuracy: {accuracy:.2f}")
print ()

precision, recall, f1_score, _ = precision_recall_fscore_support(y_test, y_pred)

for i, v in enumerate(['p1', 'p2', 'p3', 'p4']):
    print(f"Class {v}:")
    print(f"Precision: {precision[i]}")
    print(f"Recall: {recall[i]}")
    print(f"F1 Score: {f1_score[i]}")
    print()
# Out:
# Accuracy: 0.71
#
# Class p1:
# Precision: 0.719332679097154
# Recall: 0.722879684418146
# F1 Score: 0.721101819970487
#
# Class p2:
# Precision: 0.809071525489436
# Recall: 0.8273538156590684
# F1 Score: 0.8181105448843591
#
# Class p3:
# Precision: 0.34898785425101214
# Recall: 0.32528301886792454
# F1 Score: 0.33671875
#
# Class p4:
# Precision: 0.649
# Recall: 0.630709426627794
# F1 Score: 0.6397240019714144

# %%
## as XGboost gave the best results
### We will further finetune it

##Applying standard scaler

from sklearn.preprocessing import StandardScaler

columns_to_be_scaled = ['Age_Oldest_TL','Age_Newest_TL','time_since_recent_payment',
'max_recent_level_of_deliq','recent_level_of_deliq',
'time_since_recent_enq','NETMONTHLYINCOME','Time_With_Curr_Empr']

for i in columns_to_be_scaled:
    column_data = df_encoded[i].values.reshape(-1, 1)
    scaler = StandardScaler()
    scaled_column = scaler.fit_transform(column_data)
    df_encoded[i] = scaled_column

# %%
import xgboost as xgb
from sklearn.preprocessing import LabelEncoder

xgb_classifier = xgb.XGBClassifier(objective='multi:softmax',  num_class=4)

# %%
y = df_encoded['Approved_Flag']
x = df_encoded. drop ( ['Approved_Flag'], axis = 1 )

# %%
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y_encoded, test_size=0.2, random_state=42)

# %%
xgb_classifier.fit(x_train, y_train)
y_pred = xgb_classifier.predict(x_test)

accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy:.2f}')
# Out:
# Accuracy: 0.78

# %%
precision, recall, f1_score, _ = precision_recall_fscore_support(y_test, y_pred)

for i, v in enumerate(['p1', 'p2', 'p3', 'p4']):
    print(f"Class {v}:")
    print(f"Precision: {precision[i]}")
    print(f"Recall: {recall[i]}")
    print(f"F1 Score: {f1_score[i]}")
    print()
# Out:
# Class p1:
# Precision: 0.823906083244397
# Recall: 0.7613412228796844
# F1 Score: 0.7913890312660175
#
# Class p2:
# Precision: 0.8255418233924413
# Recall: 0.913577799801784
# F1 Score: 0.8673315769665035
#
# Class p3:
# Precision: 0.4756380510440835
# Recall: 0.30943396226415093
# F1 Score: 0.37494284407864653
#
# Class p4:
# Precision: 0.7342386032977691
# Recall: 0.7356656948493683
# F1 Score: 0.7349514563106796

# %%
#Hyperparameter tuning

from sklearn.model_selection import GridSearchCV
x_train, x_test, y_train, y_test = train_test_split(x, y_encoded, test_size=0.2, random_state=42)

# %%
## Define the XGBClassifier with the initial set of hyperparameters
xgb_model = xgb.XGBClassifier(objective='multi:softmax', num_class=4)

# %%
# Define the parameter grid for hyperparameter tuning

param_grid = {
    'n_estimators': [50, 100, 200],
    'max_depth': [3, 5, 7],
    'learning_rate': [0.01, 0.1, 0.2],
}

grid_search = GridSearchCV(estimator=xgb_model, param_grid=param_grid, cv=3, scoring='accuracy', n_jobs=-1)
grid_search.fit(x_train, y_train)

# Print the best hyperparameters
print("Best Hyperparameters:", grid_search.best_params_)
# Out:
# Best Hyperparameters: {'learning_rate': 0.2, 'max_depth': 3, 'n_estimators': 200}

# %%
# Evaluate the model with the best hyperparameters on the test set
best_model = grid_search.best_estimator_
accuracy = best_model.score(x_test, y_test)
print("Test Accuracy:", accuracy)
# Out:
# Test Accuracy: 0.7811719957209081

# %%
# Define the hyperparameter grid
param_grid = {
  'colsample_bytree': [0.1, 0.3, 0.5, 0.7, 0.9],
  'learning_rate'   : [0.001, 0.01, 0.1, 1],
  'max_depth'       : [3, 5, 8, 10],
  'alpha'           : [1, 10, 100],
  'n_estimators'    : [10,50,100]
}

index = 0

answers_grid = {
    'combination'       :[],
    'train_Accuracy'    :[],
    'test_Accuracy'     :[],
    'colsample_bytree'  :[],
    'learning_rate'     :[],
    'max_depth'         :[],
    'alpha'             :[],
    'n_estimators'      :[]

    }

# %%
# Loop through each combination of hyperparameters
for colsample_bytree in param_grid['colsample_bytree']:
  for learning_rate in param_grid['learning_rate']:
    for max_depth in param_grid['max_depth']:
      for alpha in param_grid['alpha']:
          for n_estimators in param_grid['n_estimators']:
             
              index = index + 1
             
              # Define and train the XGBoost model
              model = xgb.XGBClassifier(objective='multi:softmax',  
                                       num_class=4,
                                       colsample_bytree = colsample_bytree,
                                       learning_rate = learning_rate,
                                       max_depth = max_depth,
                                       alpha = alpha,
                                       n_estimators = n_estimators)
               
       
                     
              y = df_encoded['Approved_Flag']
              x = df_encoded. drop ( ['Approved_Flag'], axis = 1 )

              label_encoder = LabelEncoder()
              y_encoded = label_encoder.fit_transform(y)


              x_train, x_test, y_train, y_test = train_test_split(x, y_encoded, test_size=0.2, random_state=42)


              model.fit(x_train, y_train)
  

       
              # Predict on training and testing sets
              y_pred_train = model.predict(x_train)
              y_pred_test = model.predict(x_test)
       
       
              # Calculate train and test results
              
              train_accuracy =  accuracy_score (y_train, y_pred_train)
              test_accuracy  =  accuracy_score (y_test , y_pred_test)
              
              
       
              # Include into the lists
              answers_grid ['combination']   .append(index)
              answers_grid ['train_Accuracy']    .append(train_accuracy)
              answers_grid ['test_Accuracy']     .append(test_accuracy)
              answers_grid ['colsample_bytree']   .append(colsample_bytree)
              answers_grid ['learning_rate']      .append(learning_rate)
              answers_grid ['max_depth']          .append(max_depth)
              answers_grid ['alpha']              .append(alpha)
              answers_grid ['n_estimators']       .append(n_estimators)
       
       
              # Print results for this combination
              print(f"Combination {index}")
              print(f"colsample_bytree: {colsample_bytree}, learning_rate: {learning_rate}, max_depth: {max_depth}, alpha: {alpha}, n_estimators: {n_estimators}")
              print(f"Train Accuracy: {train_accuracy:.2f}")
              print(f"Test Accuracy : {test_accuracy :.2f}")
              print("-" * 30)
# Out:
# Combination 1
# colsample_bytree: 0.1, learning_rate: 0.001, max_depth: 3, alpha: 1, n_estimators: 10
# Train Accuracy: 0.61
# Test Accuracy : 0.61
# ------------------------------
# Combination 2
# colsample_bytree: 0.1, learning_rate: 0.001, max_depth: 3, alpha: 1, n_estimators: 50
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 3
# colsample_bytree: 0.1, learning_rate: 0.001, max_depth: 3, alpha: 1, n_estimators: 100
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 4
# colsample_bytree: 0.1, learning_rate: 0.001, max_depth: 3, alpha: 10, n_estimators: 10
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 5
# colsample_bytree: 0.1, learning_rate: 0.001, max_depth: 3, alpha: 10, n_estimators: 50
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 6
# colsample_bytree: 0.1, learning_rate: 0.001, max_depth: 3, alpha: 10, n_estimators: 100
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 7
# colsample_bytree: 0.1, learning_rate: 0.001, max_depth: 3, alpha: 100, n_estimators: 10
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 8
# colsample_bytree: 0.1, learning_rate: 0.001, max_depth: 3, alpha: 100, n_estimators: 50
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 9
# colsample_bytree: 0.1, learning_rate: 0.001, max_depth: 3, alpha: 100, n_estimators: 100
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 10
# colsample_bytree: 0.1, learning_rate: 0.001, max_depth: 5, alpha: 1, n_estimators: 10
# Train Accuracy: 0.62
# Test Accuracy : 0.61
# ------------------------------
# Combination 11
# colsample_bytree: 0.1, learning_rate: 0.001, max_depth: 5, alpha: 1, n_estimators: 50
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 12
# colsample_bytree: 0.1, learning_rate: 0.001, max_depth: 5, alpha: 1, n_estimators: 100
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 13
# colsample_bytree: 0.1, learning_rate: 0.001, max_depth: 5, alpha: 10, n_estimators: 10
# Train Accuracy: 0.61
# Test Accuracy : 0.61
# ------------------------------
# Combination 14
# colsample_bytree: 0.1, learning_rate: 0.001, max_depth: 5, alpha: 10, n_estimators: 50
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 15
# colsample_bytree: 0.1, learning_rate: 0.001, max_depth: 5, alpha: 10, n_estimators: 100
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 16
# colsample_bytree: 0.1, learning_rate: 0.001, max_depth: 5, alpha: 100, n_estimators: 10
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 17
# colsample_bytree: 0.1, learning_rate: 0.001, max_depth: 5, alpha: 100, n_estimators: 50
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 18
# colsample_bytree: 0.1, learning_rate: 0.001, max_depth: 5, alpha: 100, n_estimators: 100
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 19
# colsample_bytree: 0.1, learning_rate: 0.001, max_depth: 8, alpha: 1, n_estimators: 10
# Train Accuracy: 0.62
# Test Accuracy : 0.61
# ------------------------------
# Combination 20
# colsample_bytree: 0.1, learning_rate: 0.001, max_depth: 8, alpha: 1, n_estimators: 50
# Train Accuracy: 0.61
# Test Accuracy : 0.61
# ------------------------------
# Combination 21
# colsample_bytree: 0.1, learning_rate: 0.001, max_depth: 8, alpha: 1, n_estimators: 100
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 22
# colsample_bytree: 0.1, learning_rate: 0.001, max_depth: 8, alpha: 10, n_estimators: 10
# Train Accuracy: 0.61
# Test Accuracy : 0.61
# ------------------------------
# Combination 23
# colsample_bytree: 0.1, learning_rate: 0.001, max_depth: 8, alpha: 10, n_estimators: 50
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 24
# colsample_bytree: 0.1, learning_rate: 0.001, max_depth: 8, alpha: 10, n_estimators: 100
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 25
# colsample_bytree: 0.1, learning_rate: 0.001, max_depth: 8, alpha: 100, n_estimators: 10
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 26
# colsample_bytree: 0.1, learning_rate: 0.001, max_depth: 8, alpha: 100, n_estimators: 50
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 27
# colsample_bytree: 0.1, learning_rate: 0.001, max_depth: 8, alpha: 100, n_estimators: 100
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 28
# colsample_bytree: 0.1, learning_rate: 0.001, max_depth: 10, alpha: 1, n_estimators: 10
# Train Accuracy: 0.62
# Test Accuracy : 0.61
# ------------------------------
# Combination 29
# colsample_bytree: 0.1, learning_rate: 0.001, max_depth: 10, alpha: 1, n_estimators: 50
# Train Accuracy: 0.62
# Test Accuracy : 0.61
# ------------------------------
# Combination 30
# colsample_bytree: 0.1, learning_rate: 0.001, max_depth: 10, alpha: 1, n_estimators: 100
# Train Accuracy: 0.61
# Test Accuracy : 0.61
# ------------------------------
# Combination 31
# colsample_bytree: 0.1, learning_rate: 0.001, max_depth: 10, alpha: 10, n_estimators: 10
# Train Accuracy: 0.61
# Test Accuracy : 0.61
# ------------------------------
# Combination 32
# colsample_bytree: 0.1, learning_rate: 0.001, max_depth: 10, alpha: 10, n_estimators: 50
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 33
# colsample_bytree: 0.1, learning_rate: 0.001, max_depth: 10, alpha: 10, n_estimators: 100
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 34
# colsample_bytree: 0.1, learning_rate: 0.001, max_depth: 10, alpha: 100, n_estimators: 10
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 35
# colsample_bytree: 0.1, learning_rate: 0.001, max_depth: 10, alpha: 100, n_estimators: 50
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 36
# colsample_bytree: 0.1, learning_rate: 0.001, max_depth: 10, alpha: 100, n_estimators: 100
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 37
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 3, alpha: 1, n_estimators: 10
# Train Accuracy: 0.61
# Test Accuracy : 0.61
# ------------------------------
# Combination 38
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 3, alpha: 1, n_estimators: 50
# Train Accuracy: 0.61
# Test Accuracy : 0.61
# ------------------------------
# Combination 39
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 3, alpha: 1, n_estimators: 100
# Train Accuracy: 0.62
# Test Accuracy : 0.61
# ------------------------------
# Combination 40
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 3, alpha: 10, n_estimators: 10
# Train Accuracy: 0.61
# Test Accuracy : 0.61
# ------------------------------
# Combination 41
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 3, alpha: 10, n_estimators: 50
# Train Accuracy: 0.61
# Test Accuracy : 0.61
# ------------------------------
# Combination 42
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 3, alpha: 10, n_estimators: 100
# Train Accuracy: 0.62
# Test Accuracy : 0.61
# ------------------------------
# Combination 43
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 3, alpha: 100, n_estimators: 10
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 44
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 3, alpha: 100, n_estimators: 50
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 45
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 3, alpha: 100, n_estimators: 100
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 46
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 5, alpha: 1, n_estimators: 10
# Train Accuracy: 0.62
# Test Accuracy : 0.61
# ------------------------------
# Combination 47
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 5, alpha: 1, n_estimators: 50
# Train Accuracy: 0.62
# Test Accuracy : 0.61
# ------------------------------
# Combination 48
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 5, alpha: 1, n_estimators: 100
# Train Accuracy: 0.62
# Test Accuracy : 0.62
# ------------------------------
# Combination 49
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 5, alpha: 10, n_estimators: 10
# Train Accuracy: 0.61
# Test Accuracy : 0.61
# ------------------------------
# Combination 50
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 5, alpha: 10, n_estimators: 50
# Train Accuracy: 0.61
# Test Accuracy : 0.61
# ------------------------------
# Combination 51
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 5, alpha: 10, n_estimators: 100
# Train Accuracy: 0.62
# Test Accuracy : 0.61
# ------------------------------
# Combination 52
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 5, alpha: 100, n_estimators: 10
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 53
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 5, alpha: 100, n_estimators: 50
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 54
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 5, alpha: 100, n_estimators: 100
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 55
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 8, alpha: 1, n_estimators: 10
# Train Accuracy: 0.62
# Test Accuracy : 0.61
# ------------------------------
# Combination 56
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 8, alpha: 1, n_estimators: 50
# Train Accuracy: 0.62
# Test Accuracy : 0.61
# ------------------------------
# Combination 57
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 8, alpha: 1, n_estimators: 100
# Train Accuracy: 0.63
# Test Accuracy : 0.62
# ------------------------------
# Combination 58
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 8, alpha: 10, n_estimators: 10
# Train Accuracy: 0.62
# Test Accuracy : 0.61
# ------------------------------
# Combination 59
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 8, alpha: 10, n_estimators: 50
# Train Accuracy: 0.61
# Test Accuracy : 0.61
# ------------------------------
# Combination 60
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 8, alpha: 10, n_estimators: 100
# Train Accuracy: 0.62
# Test Accuracy : 0.61
# ------------------------------
# Combination 61
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 8, alpha: 100, n_estimators: 10
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 62
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 8, alpha: 100, n_estimators: 50
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 63
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 8, alpha: 100, n_estimators: 100
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 64
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 10, alpha: 1, n_estimators: 10
# Train Accuracy: 0.62
# Test Accuracy : 0.61
# ------------------------------
# Combination 65
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 10, alpha: 1, n_estimators: 50
# Train Accuracy: 0.62
# Test Accuracy : 0.61
# ------------------------------
# Combination 66
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 10, alpha: 1, n_estimators: 100
# Train Accuracy: 0.63
# Test Accuracy : 0.62
# ------------------------------
# Combination 67
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 10, alpha: 10, n_estimators: 10
# Train Accuracy: 0.62
# Test Accuracy : 0.61
# ------------------------------
# Combination 68
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 10, alpha: 10, n_estimators: 50
# Train Accuracy: 0.61
# Test Accuracy : 0.61
# ------------------------------
# Combination 69
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 10, alpha: 10, n_estimators: 100
# Train Accuracy: 0.62
# Test Accuracy : 0.61
# ------------------------------
# Combination 70
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 10, alpha: 100, n_estimators: 10
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 71
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 10, alpha: 100, n_estimators: 50
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 72
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 10, alpha: 100, n_estimators: 100
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 73
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 3, alpha: 1, n_estimators: 10
# Train Accuracy: 0.63
# Test Accuracy : 0.63
# ------------------------------
# Combination 74
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 3, alpha: 1, n_estimators: 50
# Train Accuracy: 0.68
# Test Accuracy : 0.68
# ------------------------------
# Combination 75
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 3, alpha: 1, n_estimators: 100
# Train Accuracy: 0.72
# Test Accuracy : 0.72
# ------------------------------
# Combination 76
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 3, alpha: 10, n_estimators: 10
# Train Accuracy: 0.63
# Test Accuracy : 0.62
# ------------------------------
# Combination 77
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 3, alpha: 10, n_estimators: 50
# Train Accuracy: 0.68
# Test Accuracy : 0.67
# ------------------------------
# Combination 78
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 3, alpha: 10, n_estimators: 100
# Train Accuracy: 0.72
# Test Accuracy : 0.72
# ------------------------------
# Combination 79
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 3, alpha: 100, n_estimators: 10
# Train Accuracy: 0.62
# Test Accuracy : 0.61
# ------------------------------
# Combination 80
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 3, alpha: 100, n_estimators: 50
# Train Accuracy: 0.67
# Test Accuracy : 0.66
# ------------------------------
# Combination 81
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 3, alpha: 100, n_estimators: 100
# Train Accuracy: 0.70
# Test Accuracy : 0.70
# ------------------------------
# Combination 82
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 5, alpha: 1, n_estimators: 10
# Train Accuracy: 0.64
# Test Accuracy : 0.63
# ------------------------------
# Combination 83
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 5, alpha: 1, n_estimators: 50
# Train Accuracy: 0.69
# Test Accuracy : 0.68
# ------------------------------
# Combination 84
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 5, alpha: 1, n_estimators: 100
# Train Accuracy: 0.74
# Test Accuracy : 0.72
# ------------------------------
# Combination 85
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 5, alpha: 10, n_estimators: 10
# Train Accuracy: 0.63
# Test Accuracy : 0.62
# ------------------------------
# Combination 86
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 5, alpha: 10, n_estimators: 50
# Train Accuracy: 0.69
# Test Accuracy : 0.68
# ------------------------------
# Combination 87
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 5, alpha: 10, n_estimators: 100
# Train Accuracy: 0.73
# Test Accuracy : 0.72
# ------------------------------
# Combination 88
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 5, alpha: 100, n_estimators: 10
# Train Accuracy: 0.62
# Test Accuracy : 0.61
# ------------------------------
# Combination 89
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 5, alpha: 100, n_estimators: 50
# Train Accuracy: 0.67
# Test Accuracy : 0.66
# ------------------------------
# Combination 90
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 5, alpha: 100, n_estimators: 100
# Train Accuracy: 0.71
# Test Accuracy : 0.70
# ------------------------------
# Combination 91
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 8, alpha: 1, n_estimators: 10
# Train Accuracy: 0.64
# Test Accuracy : 0.63
# ------------------------------
# Combination 92
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 8, alpha: 1, n_estimators: 50
# Train Accuracy: 0.71
# Test Accuracy : 0.68
# ------------------------------
# Combination 93
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 8, alpha: 1, n_estimators: 100
# Train Accuracy: 0.77
# Test Accuracy : 0.72
# ------------------------------
# Combination 94
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 8, alpha: 10, n_estimators: 10
# Train Accuracy: 0.63
# Test Accuracy : 0.62
# ------------------------------
# Combination 95
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 8, alpha: 10, n_estimators: 50
# Train Accuracy: 0.69
# Test Accuracy : 0.68
# ------------------------------
# Combination 96
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 8, alpha: 10, n_estimators: 100
# Train Accuracy: 0.73
# Test Accuracy : 0.72
# ------------------------------
# Combination 97
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 8, alpha: 100, n_estimators: 10
# Train Accuracy: 0.62
# Test Accuracy : 0.61
# ------------------------------
# Combination 98
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 8, alpha: 100, n_estimators: 50
# Train Accuracy: 0.67
# Test Accuracy : 0.66
# ------------------------------
# Combination 99
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 8, alpha: 100, n_estimators: 100
# Train Accuracy: 0.71
# Test Accuracy : 0.70
# ------------------------------
# Combination 100
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 10, alpha: 1, n_estimators: 10
# Train Accuracy: 0.64
# Test Accuracy : 0.63
# ------------------------------
# Combination 101
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 10, alpha: 1, n_estimators: 50
# Train Accuracy: 0.72
# Test Accuracy : 0.69
# ------------------------------
# Combination 102
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 10, alpha: 1, n_estimators: 100
# Train Accuracy: 0.79
# Test Accuracy : 0.72
# ------------------------------
# Combination 103
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 10, alpha: 10, n_estimators: 10
# Train Accuracy: 0.63
# Test Accuracy : 0.62
# ------------------------------
# Combination 104
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 10, alpha: 10, n_estimators: 50
# Train Accuracy: 0.69
# Test Accuracy : 0.68
# ------------------------------
# Combination 105
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 10, alpha: 10, n_estimators: 100
# Train Accuracy: 0.73
# Test Accuracy : 0.72
# ------------------------------
# Combination 106
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 10, alpha: 100, n_estimators: 10
# Train Accuracy: 0.62
# Test Accuracy : 0.61
# ------------------------------
# Combination 107
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 10, alpha: 100, n_estimators: 50
# Train Accuracy: 0.67
# Test Accuracy : 0.66
# ------------------------------
# Combination 108
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 10, alpha: 100, n_estimators: 100
# Train Accuracy: 0.71
# Test Accuracy : 0.70
# ------------------------------
# Combination 109
# colsample_bytree: 0.1, learning_rate: 1, max_depth: 3, alpha: 1, n_estimators: 10
# Train Accuracy: 0.71
# Test Accuracy : 0.71
# ------------------------------
# Combination 110
# colsample_bytree: 0.1, learning_rate: 1, max_depth: 3, alpha: 1, n_estimators: 50
# Train Accuracy: 0.78
# Test Accuracy : 0.76
# ------------------------------
# Combination 111
# colsample_bytree: 0.1, learning_rate: 1, max_depth: 3, alpha: 1, n_estimators: 100
# Train Accuracy: 0.80
# Test Accuracy : 0.77
# ------------------------------
# Combination 112
# colsample_bytree: 0.1, learning_rate: 1, max_depth: 3, alpha: 10, n_estimators: 10
# Train Accuracy: 0.71
# Test Accuracy : 0.71
# ------------------------------
# Combination 113
# colsample_bytree: 0.1, learning_rate: 1, max_depth: 3, alpha: 10, n_estimators: 50
# Train Accuracy: 0.78
# Test Accuracy : 0.76
# ------------------------------
# Combination 114
# colsample_bytree: 0.1, learning_rate: 1, max_depth: 3, alpha: 10, n_estimators: 100
# Train Accuracy: 0.79
# Test Accuracy : 0.77
# ------------------------------
# Combination 115
# colsample_bytree: 0.1, learning_rate: 1, max_depth: 3, alpha: 100, n_estimators: 10
# Train Accuracy: 0.70
# Test Accuracy : 0.70
# ------------------------------
# Combination 116
# colsample_bytree: 0.1, learning_rate: 1, max_depth: 3, alpha: 100, n_estimators: 50
# Train Accuracy: 0.75
# Test Accuracy : 0.75
# ------------------------------
# Combination 117
# colsample_bytree: 0.1, learning_rate: 1, max_depth: 3, alpha: 100, n_estimators: 100
# Train Accuracy: 0.76
# Test Accuracy : 0.76
# ------------------------------
# Combination 118
# colsample_bytree: 0.1, learning_rate: 1, max_depth: 5, alpha: 1, n_estimators: 10
# Train Accuracy: 0.73
# Test Accuracy : 0.71
# ------------------------------
# Combination 119
# colsample_bytree: 0.1, learning_rate: 1, max_depth: 5, alpha: 1, n_estimators: 50
# Train Accuracy: 0.82
# Test Accuracy : 0.76
# ------------------------------
# Combination 120
# colsample_bytree: 0.1, learning_rate: 1, max_depth: 5, alpha: 1, n_estimators: 100
# Train Accuracy: 0.86
# Test Accuracy : 0.76
# ------------------------------
# Combination 121
# colsample_bytree: 0.1, learning_rate: 1, max_depth: 5, alpha: 10, n_estimators: 10
# Train Accuracy: 0.72
# Test Accuracy : 0.71
# ------------------------------
# Combination 122
# colsample_bytree: 0.1, learning_rate: 1, max_depth: 5, alpha: 10, n_estimators: 50
# Train Accuracy: 0.79
# Test Accuracy : 0.76
# ------------------------------
# Combination 123
# colsample_bytree: 0.1, learning_rate: 1, max_depth: 5, alpha: 10, n_estimators: 100
# Train Accuracy: 0.81
# Test Accuracy : 0.77
# ------------------------------
# Combination 124
# colsample_bytree: 0.1, learning_rate: 1, max_depth: 5, alpha: 100, n_estimators: 10
# Train Accuracy: 0.70
# Test Accuracy : 0.69
# ------------------------------
# Combination 125
# colsample_bytree: 0.1, learning_rate: 1, max_depth: 5, alpha: 100, n_estimators: 50
# Train Accuracy: 0.75
# Test Accuracy : 0.75
# ------------------------------
# Combination 126
# colsample_bytree: 0.1, learning_rate: 1, max_depth: 5, alpha: 100, n_estimators: 100
# Train Accuracy: 0.76
# Test Accuracy : 0.76
# ------------------------------
# Combination 127
# colsample_bytree: 0.1, learning_rate: 1, max_depth: 8, alpha: 1, n_estimators: 10
# Train Accuracy: 0.75
# Test Accuracy : 0.71
# ------------------------------
# Combination 128
# colsample_bytree: 0.1, learning_rate: 1, max_depth: 8, alpha: 1, n_estimators: 50
# Train Accuracy: 0.89
# Test Accuracy : 0.75
# ------------------------------
# Combination 129
# colsample_bytree: 0.1, learning_rate: 1, max_depth: 8, alpha: 1, n_estimators: 100
# Train Accuracy: 0.94
# Test Accuracy : 0.75
# ------------------------------
# Combination 130
# colsample_bytree: 0.1, learning_rate: 1, max_depth: 8, alpha: 10, n_estimators: 10
# Train Accuracy: 0.72
# Test Accuracy : 0.71
# ------------------------------
# Combination 131
# colsample_bytree: 0.1, learning_rate: 1, max_depth: 8, alpha: 10, n_estimators: 50
# Train Accuracy: 0.80
# Test Accuracy : 0.76
# ------------------------------
# Combination 132
# colsample_bytree: 0.1, learning_rate: 1, max_depth: 8, alpha: 10, n_estimators: 100
# Train Accuracy: 0.82
# Test Accuracy : 0.77
# ------------------------------
# Combination 133
# colsample_bytree: 0.1, learning_rate: 1, max_depth: 8, alpha: 100, n_estimators: 10
# Train Accuracy: 0.70
# Test Accuracy : 0.69
# ------------------------------
# Combination 134
# colsample_bytree: 0.1, learning_rate: 1, max_depth: 8, alpha: 100, n_estimators: 50
# Train Accuracy: 0.75
# Test Accuracy : 0.75
# ------------------------------
# Combination 135
# colsample_bytree: 0.1, learning_rate: 1, max_depth: 8, alpha: 100, n_estimators: 100
# Train Accuracy: 0.77
# Test Accuracy : 0.76
# ------------------------------
# Combination 136
# colsample_bytree: 0.1, learning_rate: 1, max_depth: 10, alpha: 1, n_estimators: 10
# Train Accuracy: 0.77
# Test Accuracy : 0.71
# ------------------------------
# Combination 137
# colsample_bytree: 0.1, learning_rate: 1, max_depth: 10, alpha: 1, n_estimators: 50
# Train Accuracy: 0.92
# Test Accuracy : 0.74
# ------------------------------
# Combination 138
# colsample_bytree: 0.1, learning_rate: 1, max_depth: 10, alpha: 1, n_estimators: 100
# Train Accuracy: 0.97
# Test Accuracy : 0.74
# ------------------------------
# Combination 139
# colsample_bytree: 0.1, learning_rate: 1, max_depth: 10, alpha: 10, n_estimators: 10
# Train Accuracy: 0.72
# Test Accuracy : 0.71
# ------------------------------
# Combination 140
# colsample_bytree: 0.1, learning_rate: 1, max_depth: 10, alpha: 10, n_estimators: 50
# Train Accuracy: 0.80
# Test Accuracy : 0.76
# ------------------------------
# Combination 141
# colsample_bytree: 0.1, learning_rate: 1, max_depth: 10, alpha: 10, n_estimators: 100
# Train Accuracy: 0.83
# Test Accuracy : 0.76
# ------------------------------
# Combination 142
# colsample_bytree: 0.1, learning_rate: 1, max_depth: 10, alpha: 100, n_estimators: 10
# Train Accuracy: 0.70
# Test Accuracy : 0.69
# ------------------------------
# Combination 143
# colsample_bytree: 0.1, learning_rate: 1, max_depth: 10, alpha: 100, n_estimators: 50
# Train Accuracy: 0.75
# Test Accuracy : 0.75
# ------------------------------
# Combination 144
# colsample_bytree: 0.1, learning_rate: 1, max_depth: 10, alpha: 100, n_estimators: 100
# Train Accuracy: 0.77
# Test Accuracy : 0.76
# ------------------------------
# Combination 145
# colsample_bytree: 0.3, learning_rate: 0.001, max_depth: 3, alpha: 1, n_estimators: 10
# Train Accuracy: 0.67
# Test Accuracy : 0.67
# ------------------------------
# Combination 146
# colsample_bytree: 0.3, learning_rate: 0.001, max_depth: 3, alpha: 1, n_estimators: 50
# Train Accuracy: 0.67
# Test Accuracy : 0.66
# ------------------------------
# Combination 147
# colsample_bytree: 0.3, learning_rate: 0.001, max_depth: 3, alpha: 1, n_estimators: 100
# Train Accuracy: 0.66
# Test Accuracy : 0.66
# ------------------------------
# Combination 148
# colsample_bytree: 0.3, learning_rate: 0.001, max_depth: 3, alpha: 10, n_estimators: 10
# Train Accuracy: 0.67
# Test Accuracy : 0.67
# ------------------------------
# Combination 149
# colsample_bytree: 0.3, learning_rate: 0.001, max_depth: 3, alpha: 10, n_estimators: 50
# Train Accuracy: 0.67
# Test Accuracy : 0.66
# ------------------------------
# Combination 150
# colsample_bytree: 0.3, learning_rate: 0.001, max_depth: 3, alpha: 10, n_estimators: 100
# Train Accuracy: 0.66
# Test Accuracy : 0.66
# ------------------------------
# Combination 151
# colsample_bytree: 0.3, learning_rate: 0.001, max_depth: 3, alpha: 100, n_estimators: 10
# Train Accuracy: 0.67
# Test Accuracy : 0.66
# ------------------------------
# Combination 152
# colsample_bytree: 0.3, learning_rate: 0.001, max_depth: 3, alpha: 100, n_estimators: 50
# Train Accuracy: 0.66
# Test Accuracy : 0.66
# ------------------------------
# Combination 153
# colsample_bytree: 0.3, learning_rate: 0.001, max_depth: 3, alpha: 100, n_estimators: 100
# Train Accuracy: 0.66
# Test Accuracy : 0.65
# ------------------------------
# Combination 154
# colsample_bytree: 0.3, learning_rate: 0.001, max_depth: 5, alpha: 1, n_estimators: 10
# Train Accuracy: 0.70
# Test Accuracy : 0.69
# ------------------------------
# Combination 155
# colsample_bytree: 0.3, learning_rate: 0.001, max_depth: 5, alpha: 1, n_estimators: 50
# Train Accuracy: 0.69
# Test Accuracy : 0.68
# ------------------------------
# Combination 156
# colsample_bytree: 0.3, learning_rate: 0.001, max_depth: 5, alpha: 1, n_estimators: 100
# Train Accuracy: 0.69
# Test Accuracy : 0.68
# ------------------------------
# Combination 157
# colsample_bytree: 0.3, learning_rate: 0.001, max_depth: 5, alpha: 10, n_estimators: 10
# Train Accuracy: 0.69
# Test Accuracy : 0.69
# ------------------------------
# Combination 158
# colsample_bytree: 0.3, learning_rate: 0.001, max_depth: 5, alpha: 10, n_estimators: 50
# Train Accuracy: 0.68
# Test Accuracy : 0.68
# ------------------------------
# Combination 159
# colsample_bytree: 0.3, learning_rate: 0.001, max_depth: 5, alpha: 10, n_estimators: 100
# Train Accuracy: 0.68
# Test Accuracy : 0.68
# ------------------------------
# Combination 160
# colsample_bytree: 0.3, learning_rate: 0.001, max_depth: 5, alpha: 100, n_estimators: 10
# Train Accuracy: 0.67
# Test Accuracy : 0.67
# ------------------------------
# Combination 161
# colsample_bytree: 0.3, learning_rate: 0.001, max_depth: 5, alpha: 100, n_estimators: 50
# Train Accuracy: 0.67
# Test Accuracy : 0.66
# ------------------------------
# Combination 162
# colsample_bytree: 0.3, learning_rate: 0.001, max_depth: 5, alpha: 100, n_estimators: 100
# Train Accuracy: 0.66
# Test Accuracy : 0.66
# ------------------------------
# Combination 163
# colsample_bytree: 0.3, learning_rate: 0.001, max_depth: 8, alpha: 1, n_estimators: 10
# Train Accuracy: 0.72
# Test Accuracy : 0.70
# ------------------------------
# Combination 164
# colsample_bytree: 0.3, learning_rate: 0.001, max_depth: 8, alpha: 1, n_estimators: 50
# Train Accuracy: 0.71
# Test Accuracy : 0.69
# ------------------------------
# Combination 165
# colsample_bytree: 0.3, learning_rate: 0.001, max_depth: 8, alpha: 1, n_estimators: 100
# Train Accuracy: 0.71
# Test Accuracy : 0.69
# ------------------------------
# Combination 166
# colsample_bytree: 0.3, learning_rate: 0.001, max_depth: 8, alpha: 10, n_estimators: 10
# Train Accuracy: 0.70
# Test Accuracy : 0.69
# ------------------------------
# Combination 167
# colsample_bytree: 0.3, learning_rate: 0.001, max_depth: 8, alpha: 10, n_estimators: 50
# Train Accuracy: 0.70
# Test Accuracy : 0.69
# ------------------------------
# Combination 168
# colsample_bytree: 0.3, learning_rate: 0.001, max_depth: 8, alpha: 10, n_estimators: 100
# Train Accuracy: 0.70
# Test Accuracy : 0.68
# ------------------------------
# Combination 169
# colsample_bytree: 0.3, learning_rate: 0.001, max_depth: 8, alpha: 100, n_estimators: 10
# Train Accuracy: 0.67
# Test Accuracy : 0.67
# ------------------------------
# Combination 170
# colsample_bytree: 0.3, learning_rate: 0.001, max_depth: 8, alpha: 100, n_estimators: 50
# Train Accuracy: 0.67
# Test Accuracy : 0.66
# ------------------------------
# Combination 171
# colsample_bytree: 0.3, learning_rate: 0.001, max_depth: 8, alpha: 100, n_estimators: 100
# Train Accuracy: 0.66
# Test Accuracy : 0.66
# ------------------------------
# Combination 172
# colsample_bytree: 0.3, learning_rate: 0.001, max_depth: 10, alpha: 1, n_estimators: 10
# Train Accuracy: 0.74
# Test Accuracy : 0.70
# ------------------------------
# Combination 173
# colsample_bytree: 0.3, learning_rate: 0.001, max_depth: 10, alpha: 1, n_estimators: 50
# Train Accuracy: 0.73
# Test Accuracy : 0.70
# ------------------------------
# Combination 174
# colsample_bytree: 0.3, learning_rate: 0.001, max_depth: 10, alpha: 1, n_estimators: 100
# Train Accuracy: 0.73
# Test Accuracy : 0.69
# ------------------------------
# Combination 175
# colsample_bytree: 0.3, learning_rate: 0.001, max_depth: 10, alpha: 10, n_estimators: 10
# Train Accuracy: 0.70
# Test Accuracy : 0.69
# ------------------------------
# Combination 176
# colsample_bytree: 0.3, learning_rate: 0.001, max_depth: 10, alpha: 10, n_estimators: 50
# Train Accuracy: 0.70
# Test Accuracy : 0.69
# ------------------------------
# Combination 177
# colsample_bytree: 0.3, learning_rate: 0.001, max_depth: 10, alpha: 10, n_estimators: 100
# Train Accuracy: 0.70
# Test Accuracy : 0.69
# ------------------------------
# Combination 178
# colsample_bytree: 0.3, learning_rate: 0.001, max_depth: 10, alpha: 100, n_estimators: 10
# Train Accuracy: 0.68
# Test Accuracy : 0.67
# ------------------------------
# Combination 179
# colsample_bytree: 0.3, learning_rate: 0.001, max_depth: 10, alpha: 100, n_estimators: 50
# Train Accuracy: 0.67
# Test Accuracy : 0.66
# ------------------------------
# Combination 180
# colsample_bytree: 0.3, learning_rate: 0.001, max_depth: 10, alpha: 100, n_estimators: 100
# Train Accuracy: 0.66
# Test Accuracy : 0.66
# ------------------------------
# Combination 181
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 3, alpha: 1, n_estimators: 10
# Train Accuracy: 0.67
# Test Accuracy : 0.67
# ------------------------------
# Combination 182
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 3, alpha: 1, n_estimators: 50
# Train Accuracy: 0.68
# Test Accuracy : 0.67
# ------------------------------
# Combination 183
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 3, alpha: 1, n_estimators: 100
# Train Accuracy: 0.68
# Test Accuracy : 0.68
# ------------------------------
# Combination 184
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 3, alpha: 10, n_estimators: 10
# Train Accuracy: 0.67
# Test Accuracy : 0.67
# ------------------------------
# Combination 185
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 3, alpha: 10, n_estimators: 50
# Train Accuracy: 0.68
# Test Accuracy : 0.67
# ------------------------------
# Combination 186
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 3, alpha: 10, n_estimators: 100
# Train Accuracy: 0.68
# Test Accuracy : 0.68
# ------------------------------
# Combination 187
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 3, alpha: 100, n_estimators: 10
# Train Accuracy: 0.67
# Test Accuracy : 0.66
# ------------------------------
# Combination 188
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 3, alpha: 100, n_estimators: 50
# Train Accuracy: 0.67
# Test Accuracy : 0.66
# ------------------------------
# Combination 189
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 3, alpha: 100, n_estimators: 100
# Train Accuracy: 0.67
# Test Accuracy : 0.67
# ------------------------------
# Combination 190
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 5, alpha: 1, n_estimators: 10
# Train Accuracy: 0.70
# Test Accuracy : 0.69
# ------------------------------
# Combination 191
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 5, alpha: 1, n_estimators: 50
# Train Accuracy: 0.70
# Test Accuracy : 0.69
# ------------------------------
# Combination 192
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 5, alpha: 1, n_estimators: 100
# Train Accuracy: 0.71
# Test Accuracy : 0.70
# ------------------------------
# Combination 193
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 5, alpha: 10, n_estimators: 10
# Train Accuracy: 0.69
# Test Accuracy : 0.69
# ------------------------------
# Combination 194
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 5, alpha: 10, n_estimators: 50
# Train Accuracy: 0.70
# Test Accuracy : 0.69
# ------------------------------
# Combination 195
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 5, alpha: 10, n_estimators: 100
# Train Accuracy: 0.70
# Test Accuracy : 0.69
# ------------------------------
# Combination 196
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 5, alpha: 100, n_estimators: 10
# Train Accuracy: 0.68
# Test Accuracy : 0.67
# ------------------------------
# Combination 197
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 5, alpha: 100, n_estimators: 50
# Train Accuracy: 0.67
# Test Accuracy : 0.67
# ------------------------------
# Combination 198
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 5, alpha: 100, n_estimators: 100
# Train Accuracy: 0.68
# Test Accuracy : 0.68
# ------------------------------
# Combination 199
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 8, alpha: 1, n_estimators: 10
# Train Accuracy: 0.72
# Test Accuracy : 0.70
# ------------------------------
# Combination 200
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 8, alpha: 1, n_estimators: 50
# Train Accuracy: 0.73
# Test Accuracy : 0.70
# ------------------------------
# Combination 201
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 8, alpha: 1, n_estimators: 100
# Train Accuracy: 0.74
# Test Accuracy : 0.71
# ------------------------------
# Combination 202
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 8, alpha: 10, n_estimators: 10
# Train Accuracy: 0.71
# Test Accuracy : 0.70
# ------------------------------
# Combination 203
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 8, alpha: 10, n_estimators: 50
# Train Accuracy: 0.71
# Test Accuracy : 0.70
# ------------------------------
# Combination 204
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 8, alpha: 10, n_estimators: 100
# Train Accuracy: 0.72
# Test Accuracy : 0.70
# ------------------------------
# Combination 205
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 8, alpha: 100, n_estimators: 10
# Train Accuracy: 0.68
# Test Accuracy : 0.67
# ------------------------------
# Combination 206
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 8, alpha: 100, n_estimators: 50
# Train Accuracy: 0.67
# Test Accuracy : 0.67
# ------------------------------
# Combination 207
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 8, alpha: 100, n_estimators: 100
# Train Accuracy: 0.68
# Test Accuracy : 0.68
# ------------------------------
# Combination 208
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 10, alpha: 1, n_estimators: 10
# Train Accuracy: 0.74
# Test Accuracy : 0.70
# ------------------------------
# Combination 209
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 10, alpha: 1, n_estimators: 50
# Train Accuracy: 0.75
# Test Accuracy : 0.71
# ------------------------------
# Combination 210
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 10, alpha: 1, n_estimators: 100
# Train Accuracy: 0.76
# Test Accuracy : 0.71
# ------------------------------
# Combination 211
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 10, alpha: 10, n_estimators: 10
# Train Accuracy: 0.71
# Test Accuracy : 0.70
# ------------------------------
# Combination 212
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 10, alpha: 10, n_estimators: 50
# Train Accuracy: 0.71
# Test Accuracy : 0.70
# ------------------------------
# Combination 213
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 10, alpha: 10, n_estimators: 100
# Train Accuracy: 0.72
# Test Accuracy : 0.70
# ------------------------------
# Combination 214
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 10, alpha: 100, n_estimators: 10
# Train Accuracy: 0.68
# Test Accuracy : 0.67
# ------------------------------
# Combination 215
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 10, alpha: 100, n_estimators: 50
# Train Accuracy: 0.67
# Test Accuracy : 0.67
# ------------------------------
# Combination 216
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 10, alpha: 100, n_estimators: 100
# Train Accuracy: 0.68
# Test Accuracy : 0.68
# ------------------------------
# Combination 217
# colsample_bytree: 0.3, learning_rate: 0.1, max_depth: 3, alpha: 1, n_estimators: 10
# Train Accuracy: 0.69
# Test Accuracy : 0.69
# ------------------------------
# Combination 218
# colsample_bytree: 0.3, learning_rate: 0.1, max_depth: 3, alpha: 1, n_estimators: 50
# Train Accuracy: 0.74
# Test Accuracy : 0.73
# ------------------------------
# Combination 219
# colsample_bytree: 0.3, learning_rate: 0.1, max_depth: 3, alpha: 1, n_estimators: 100
# Train Accuracy: 0.77
# Test Accuracy : 0.76
# ------------------------------
# Combination 220
# colsample_bytree: 0.3, learning_rate: 0.1, max_depth: 3, alpha: 10, n_estimators: 10
# Train Accuracy: 0.69
# Test Accuracy : 0.69
# ------------------------------
# Combination 221
# colsample_bytree: 0.3, learning_rate: 0.1, max_depth: 3, alpha: 10, n_estimators: 50
# Train Accuracy: 0.74
# Test Accuracy : 0.73
# ------------------------------
# Combination 222
# colsample_bytree: 0.3, learning_rate: 0.1, max_depth: 3, alpha: 10, n_estimators: 100
# Train Accuracy: 0.77
# Test Accuracy : 0.76
# ------------------------------
# Combination 223
# colsample_bytree: 0.3, learning_rate: 0.1, max_depth: 3, alpha: 100, n_estimators: 10
# Train Accuracy: 0.69
# Test Accuracy : 0.68
# ------------------------------
# Combination 224
# colsample_bytree: 0.3, learning_rate: 0.1, max_depth: 3, alpha: 100, n_estimators: 50
# Train Accuracy: 0.73
# Test Accuracy : 0.72
# ------------------------------
# Combination 225
# colsample_bytree: 0.3, learning_rate: 0.1, max_depth: 3, alpha: 100, n_estimators: 100
# Train Accuracy: 0.75
# Test Accuracy : 0.74
# ------------------------------
# Combination 226
# colsample_bytree: 0.3, learning_rate: 0.1, max_depth: 5, alpha: 1, n_estimators: 10
# Train Accuracy: 0.72
# Test Accuracy : 0.71
# ------------------------------
# Combination 227
# colsample_bytree: 0.3, learning_rate: 0.1, max_depth: 5, alpha: 1, n_estimators: 50
# Train Accuracy: 0.77
# Test Accuracy : 0.75
# ------------------------------
# Combination 228
# colsample_bytree: 0.3, learning_rate: 0.1, max_depth: 5, alpha: 1, n_estimators: 100
# Train Accuracy: 0.80
# Test Accuracy : 0.77
# ------------------------------
# Combination 229
# colsample_bytree: 0.3, learning_rate: 0.1, max_depth: 5, alpha: 10, n_estimators: 10
# Train Accuracy: 0.71
# Test Accuracy : 0.71
# ------------------------------
# Combination 230
# colsample_bytree: 0.3, learning_rate: 0.1, max_depth: 5, alpha: 10, n_estimators: 50
# Train Accuracy: 0.76
# Test Accuracy : 0.75
# ------------------------------
# Combination 231
# colsample_bytree: 0.3, learning_rate: 0.1, max_depth: 5, alpha: 10, n_estimators: 100
# Train Accuracy: 0.79
# Test Accuracy : 0.77
# ------------------------------
# Combination 232
# colsample_bytree: 0.3, learning_rate: 0.1, max_depth: 5, alpha: 100, n_estimators: 10
# Train Accuracy: 0.69
# Test Accuracy : 0.68
# ------------------------------
# Combination 233
# colsample_bytree: 0.3, learning_rate: 0.1, max_depth: 5, alpha: 100, n_estimators: 50
# Train Accuracy: 0.74
# Test Accuracy : 0.72
# ------------------------------
# Combination 234
# colsample_bytree: 0.3, learning_rate: 0.1, max_depth: 5, alpha: 100, n_estimators: 100
# Train Accuracy: 0.76
# Test Accuracy : 0.75
# ------------------------------
# Combination 235
# colsample_bytree: 0.3, learning_rate: 0.1, max_depth: 8, alpha: 1, n_estimators: 10
# Train Accuracy: 0.75
# Test Accuracy : 0.72
# ------------------------------
# Combination 236
# colsample_bytree: 0.3, learning_rate: 0.1, max_depth: 8, alpha: 1, n_estimators: 50
# Train Accuracy: 0.82
# Test Accuracy : 0.76
# ------------------------------
# Combination 237
# colsample_bytree: 0.3, learning_rate: 0.1, max_depth: 8, alpha: 1, n_estimators: 100
# Train Accuracy: 0.86
# Test Accuracy : 0.77
# ------------------------------
# Combination 238
# colsample_bytree: 0.3, learning_rate: 0.1, max_depth: 8, alpha: 10, n_estimators: 10
# Train Accuracy: 0.73
# Test Accuracy : 0.71
# ------------------------------
# Combination 239
# colsample_bytree: 0.3, learning_rate: 0.1, max_depth: 8, alpha: 10, n_estimators: 50
# Train Accuracy: 0.78
# Test Accuracy : 0.75
# ------------------------------
# Combination 240
# colsample_bytree: 0.3, learning_rate: 0.1, max_depth: 8, alpha: 10, n_estimators: 100
# Train Accuracy: 0.80
# Test Accuracy : 0.77
# ------------------------------
# Combination 241
# colsample_bytree: 0.3, learning_rate: 0.1, max_depth: 8, alpha: 100, n_estimators: 10
# Train Accuracy: 0.69
# Test Accuracy : 0.68
# ------------------------------
# Combination 242
# colsample_bytree: 0.3, learning_rate: 0.1, max_depth: 8, alpha: 100, n_estimators: 50
# Train Accuracy: 0.74
# Test Accuracy : 0.73
# ------------------------------
# Combination 243
# colsample_bytree: 0.3, learning_rate: 0.1, max_depth: 8, alpha: 100, n_estimators: 100
# Train Accuracy: 0.76
# Test Accuracy : 0.75
# ------------------------------
# Combination 244
# colsample_bytree: 0.3, learning_rate: 0.1, max_depth: 10, alpha: 1, n_estimators: 10
# Train Accuracy: 0.77
# Test Accuracy : 0.72
# ------------------------------
# Combination 245
# colsample_bytree: 0.3, learning_rate: 0.1, max_depth: 10, alpha: 1, n_estimators: 50
# Train Accuracy: 0.86
# Test Accuracy : 0.75
# ------------------------------
# Combination 246
# colsample_bytree: 0.3, learning_rate: 0.1, max_depth: 10, alpha: 1, n_estimators: 100
# Train Accuracy: 0.92
# Test Accuracy : 0.77
# ------------------------------
# Combination 247
# colsample_bytree: 0.3, learning_rate: 0.1, max_depth: 10, alpha: 10, n_estimators: 10
# Train Accuracy: 0.73
# Test Accuracy : 0.71
# ------------------------------
# Combination 248
# colsample_bytree: 0.3, learning_rate: 0.1, max_depth: 10, alpha: 10, n_estimators: 50
# Train Accuracy: 0.78
# Test Accuracy : 0.76
# ------------------------------
# Combination 249
# colsample_bytree: 0.3, learning_rate: 0.1, max_depth: 10, alpha: 10, n_estimators: 100
# Train Accuracy: 0.81
# Test Accuracy : 0.77
# ------------------------------
# Combination 250
# colsample_bytree: 0.3, learning_rate: 0.1, max_depth: 10, alpha: 100, n_estimators: 10
# Train Accuracy: 0.69
# Test Accuracy : 0.68
# ------------------------------
# Combination 251
# colsample_bytree: 0.3, learning_rate: 0.1, max_depth: 10, alpha: 100, n_estimators: 50
# Train Accuracy: 0.74
# Test Accuracy : 0.73
# ------------------------------
# Combination 252
# colsample_bytree: 0.3, learning_rate: 0.1, max_depth: 10, alpha: 100, n_estimators: 100
# Train Accuracy: 0.76
# Test Accuracy : 0.75
# ------------------------------
# Combination 253
# colsample_bytree: 0.3, learning_rate: 1, max_depth: 3, alpha: 1, n_estimators: 10
# Train Accuracy: 0.76
# Test Accuracy : 0.76
# ------------------------------
# Combination 254
# colsample_bytree: 0.3, learning_rate: 1, max_depth: 3, alpha: 1, n_estimators: 50
# Train Accuracy: 0.80
# Test Accuracy : 0.78
# ------------------------------
# Combination 255
# colsample_bytree: 0.3, learning_rate: 1, max_depth: 3, alpha: 1, n_estimators: 100
# Train Accuracy: 0.83
# Test Accuracy : 0.78
# ------------------------------
# Combination 256
# colsample_bytree: 0.3, learning_rate: 1, max_depth: 3, alpha: 10, n_estimators: 10
# Train Accuracy: 0.76
# Test Accuracy : 0.76
# ------------------------------
# Combination 257
# colsample_bytree: 0.3, learning_rate: 1, max_depth: 3, alpha: 10, n_estimators: 50
# Train Accuracy: 0.80
# Test Accuracy : 0.78
# ------------------------------
# Combination 258
# colsample_bytree: 0.3, learning_rate: 1, max_depth: 3, alpha: 10, n_estimators: 100
# Train Accuracy: 0.81
# Test Accuracy : 0.78
# ------------------------------
# Combination 259
# colsample_bytree: 0.3, learning_rate: 1, max_depth: 3, alpha: 100, n_estimators: 10
# Train Accuracy: 0.75
# Test Accuracy : 0.74
# ------------------------------
# Combination 260
# colsample_bytree: 0.3, learning_rate: 1, max_depth: 3, alpha: 100, n_estimators: 50
# Train Accuracy: 0.77
# Test Accuracy : 0.76
# ------------------------------
# Combination 261
# colsample_bytree: 0.3, learning_rate: 1, max_depth: 3, alpha: 100, n_estimators: 100
# Train Accuracy: 0.77
# Test Accuracy : 0.76
# ------------------------------
# Combination 262
# colsample_bytree: 0.3, learning_rate: 1, max_depth: 5, alpha: 1, n_estimators: 10
# Train Accuracy: 0.79
# Test Accuracy : 0.76
# ------------------------------
# Combination 263
# colsample_bytree: 0.3, learning_rate: 1, max_depth: 5, alpha: 1, n_estimators: 50
# Train Accuracy: 0.86
# Test Accuracy : 0.77
# ------------------------------
# Combination 264
# colsample_bytree: 0.3, learning_rate: 1, max_depth: 5, alpha: 1, n_estimators: 100
# Train Accuracy: 0.91
# Test Accuracy : 0.77
# ------------------------------
# Combination 265
# colsample_bytree: 0.3, learning_rate: 1, max_depth: 5, alpha: 10, n_estimators: 10
# Train Accuracy: 0.78
# Test Accuracy : 0.77
# ------------------------------
# Combination 266
# colsample_bytree: 0.3, learning_rate: 1, max_depth: 5, alpha: 10, n_estimators: 50
# Train Accuracy: 0.82
# Test Accuracy : 0.77
# ------------------------------
# Combination 267
# colsample_bytree: 0.3, learning_rate: 1, max_depth: 5, alpha: 10, n_estimators: 100
# Train Accuracy: 0.85
# Test Accuracy : 0.77
# ------------------------------
# Combination 268
# colsample_bytree: 0.3, learning_rate: 1, max_depth: 5, alpha: 100, n_estimators: 10
# Train Accuracy: 0.76
# Test Accuracy : 0.76
# ------------------------------
# Combination 269
# colsample_bytree: 0.3, learning_rate: 1, max_depth: 5, alpha: 100, n_estimators: 50
# Train Accuracy: 0.78
# Test Accuracy : 0.77
# ------------------------------
# Combination 270
# colsample_bytree: 0.3, learning_rate: 1, max_depth: 5, alpha: 100, n_estimators: 100
# Train Accuracy: 0.78
# Test Accuracy : 0.77
# ------------------------------
# Combination 271
# colsample_bytree: 0.3, learning_rate: 1, max_depth: 8, alpha: 1, n_estimators: 10
# Train Accuracy: 0.86
# Test Accuracy : 0.76
# ------------------------------
# Combination 272
# colsample_bytree: 0.3, learning_rate: 1, max_depth: 8, alpha: 1, n_estimators: 50
# Train Accuracy: 0.97
# Test Accuracy : 0.76
# ------------------------------
# Combination 273
# colsample_bytree: 0.3, learning_rate: 1, max_depth: 8, alpha: 1, n_estimators: 100
# Train Accuracy: 1.00
# Test Accuracy : 0.76
# ------------------------------
# Combination 274
# colsample_bytree: 0.3, learning_rate: 1, max_depth: 8, alpha: 10, n_estimators: 10
# Train Accuracy: 0.80
# Test Accuracy : 0.76
# ------------------------------
# Combination 275
# colsample_bytree: 0.3, learning_rate: 1, max_depth: 8, alpha: 10, n_estimators: 50
# Train Accuracy: 0.86
# Test Accuracy : 0.77
# ------------------------------
# ...
# Combination 359
# colsample_bytree: 0.5, learning_rate: 0.01, max_depth: 10, alpha: 100, n_estimators: 50
# Train Accuracy: 0.72
# Test Accuracy : 0.71
# ------------------------------
# Combination 360
# colsample_bytree: 0.5, learning_rate: 0.01, max_depth: 10, alpha: 100, n_estimators: 100
# Train Accuracy: 0.73
# Test Accuracy : 0.72
# ------------------------------
# Combination 361
# colsample_bytree: 0.5, learning_rate: 0.1, max_depth: 3, alpha: 1, n_estimators: 10
# Train Accuracy: 0.72
# Test Accuracy : 0.71
# ------------------------------
# Combination 362
# colsample_bytree: 0.5, learning_rate: 0.1, max_depth: 3, alpha: 1, n_estimators: 50
# Train Accuracy: 0.76
# Test Accuracy : 0.75
# ------------------------------
# Combination 363
# colsample_bytree: 0.5, learning_rate: 0.1, max_depth: 3, alpha: 1, n_estimators: 100
# Train Accuracy: 0.78
# Test Accuracy : 0.77
# ------------------------------
# Combination 364
# colsample_bytree: 0.5, learning_rate: 0.1, max_depth: 3, alpha: 10, n_estimators: 10
# Train Accuracy: 0.71
# Test Accuracy : 0.71
# ------------------------------
# Combination 365
# colsample_bytree: 0.5, learning_rate: 0.1, max_depth: 3, alpha: 10, n_estimators: 50
# Train Accuracy: 0.76
# Test Accuracy : 0.75
# ------------------------------
# Combination 366
# colsample_bytree: 0.5, learning_rate: 0.1, max_depth: 3, alpha: 10, n_estimators: 100
# Train Accuracy: 0.77
# Test Accuracy : 0.77
# ------------------------------
# Combination 367
# colsample_bytree: 0.5, learning_rate: 0.1, max_depth: 3, alpha: 100, n_estimators: 10
# Train Accuracy: 0.71
# Test Accuracy : 0.70
# ------------------------------
# Combination 368
# colsample_bytree: 0.5, learning_rate: 0.1, max_depth: 3, alpha: 100, n_estimators: 50
# Train Accuracy: 0.74
# Test Accuracy : 0.74
# ------------------------------
# Combination 369
# colsample_bytree: 0.5, learning_rate: 0.1, max_depth: 3, alpha: 100, n_estimators: 100
# Train Accuracy: 0.76
# Test Accuracy : 0.76
# ------------------------------
# Combination 370
# colsample_bytree: 0.5, learning_rate: 0.1, max_depth: 5, alpha: 1, n_estimators: 10
# Train Accuracy: 0.75
# Test Accuracy : 0.74
# ------------------------------
# Combination 371
# colsample_bytree: 0.5, learning_rate: 0.1, max_depth: 5, alpha: 1, n_estimators: 50
# Train Accuracy: 0.79
# Test Accuracy : 0.77
# ------------------------------
# Combination 372
# colsample_bytree: 0.5, learning_rate: 0.1, max_depth: 5, alpha: 1, n_estimators: 100
# Train Accuracy: 0.80
# Test Accuracy : 0.77
# ------------------------------
# Combination 373
# colsample_bytree: 0.5, learning_rate: 0.1, max_depth: 5, alpha: 10, n_estimators: 10
# Train Accuracy: 0.75
# Test Accuracy : 0.74
# ------------------------------
# Combination 374
# colsample_bytree: 0.5, learning_rate: 0.1, max_depth: 5, alpha: 10, n_estimators: 50
# Train Accuracy: 0.78
# Test Accuracy : 0.77
# ------------------------------
# Combination 375
# colsample_bytree: 0.5, learning_rate: 0.1, max_depth: 5, alpha: 10, n_estimators: 100
# Train Accuracy: 0.79
# Test Accuracy : 0.78
# ------------------------------
# Combination 376
# colsample_bytree: 0.5, learning_rate: 0.1, max_depth: 5, alpha: 100, n_estimators: 10
# Train Accuracy: 0.72
# Test Accuracy : 0.72
# ------------------------------
# Combination 377
# colsample_bytree: 0.5, learning_rate: 0.1, max_depth: 5, alpha: 100, n_estimators: 50
# Train Accuracy: 0.76
# Test Accuracy : 0.75
# ------------------------------
# Combination 378
# colsample_bytree: 0.5, learning_rate: 0.1, max_depth: 5, alpha: 100, n_estimators: 100
# Train Accuracy: 0.77
# Test Accuracy : 0.77
# ------------------------------
# Combination 379
# colsample_bytree: 0.5, learning_rate: 0.1, max_depth: 8, alpha: 1, n_estimators: 10
# Train Accuracy: 0.79
# Test Accuracy : 0.75
# ------------------------------
# Combination 380
# colsample_bytree: 0.5, learning_rate: 0.1, max_depth: 8, alpha: 1, n_estimators: 50
# Train Accuracy: 0.84
# Test Accuracy : 0.77
# ------------------------------
# Combination 381
# colsample_bytree: 0.5, learning_rate: 0.1, max_depth: 8, alpha: 1, n_estimators: 100
# Train Accuracy: 0.87
# Test Accuracy : 0.78
# ------------------------------
# Combination 382
# colsample_bytree: 0.5, learning_rate: 0.1, max_depth: 8, alpha: 10, n_estimators: 10
# Train Accuracy: 0.77
# Test Accuracy : 0.75
# ------------------------------
# Combination 383
# colsample_bytree: 0.5, learning_rate: 0.1, max_depth: 8, alpha: 10, n_estimators: 50
# Train Accuracy: 0.80
# Test Accuracy : 0.77
# ------------------------------
# Combination 384
# colsample_bytree: 0.5, learning_rate: 0.1, max_depth: 8, alpha: 10, n_estimators: 100
# Train Accuracy: 0.82
# Test Accuracy : 0.78
# ------------------------------
# Combination 385
# colsample_bytree: 0.5, learning_rate: 0.1, max_depth: 8, alpha: 100, n_estimators: 10
# Train Accuracy: 0.73
# Test Accuracy : 0.72
# ------------------------------
# Combination 386
# colsample_bytree: 0.5, learning_rate: 0.1, max_depth: 8, alpha: 100, n_estimators: 50
# Train Accuracy: 0.76
# Test Accuracy : 0.75
# ------------------------------
# Combination 387
# colsample_bytree: 0.5, learning_rate: 0.1, max_depth: 8, alpha: 100, n_estimators: 100
# Train Accuracy: 0.78
# Test Accuracy : 0.77
# ------------------------------
# Combination 388
# colsample_bytree: 0.5, learning_rate: 0.1, max_depth: 10, alpha: 1, n_estimators: 10
# Train Accuracy: 0.82
# Test Accuracy : 0.75
# ------------------------------
# Combination 389
# colsample_bytree: 0.5, learning_rate: 0.1, max_depth: 10, alpha: 1, n_estimators: 50
# Train Accuracy: 0.89
# Test Accuracy : 0.77
# ------------------------------
# Combination 390
# colsample_bytree: 0.5, learning_rate: 0.1, max_depth: 10, alpha: 1, n_estimators: 100
# Train Accuracy: 0.93
# Test Accuracy : 0.77
# ------------------------------
# Combination 391
# colsample_bytree: 0.5, learning_rate: 0.1, max_depth: 10, alpha: 10, n_estimators: 10
# Train Accuracy: 0.77
# Test Accuracy : 0.75
# ------------------------------
# Combination 392
# colsample_bytree: 0.5, learning_rate: 0.1, max_depth: 10, alpha: 10, n_estimators: 50
# Train Accuracy: 0.81
# Test Accuracy : 0.77
# ------------------------------
# Combination 393
# colsample_bytree: 0.5, learning_rate: 0.1, max_depth: 10, alpha: 10, n_estimators: 100
# Train Accuracy: 0.83
# Test Accuracy : 0.78
# ------------------------------
# Combination 394
# colsample_bytree: 0.5, learning_rate: 0.1, max_depth: 10, alpha: 100, n_estimators: 10
# Train Accuracy: 0.73
# Test Accuracy : 0.72
# ------------------------------
# Combination 395
# colsample_bytree: 0.5, learning_rate: 0.1, max_depth: 10, alpha: 100, n_estimators: 50
# Train Accuracy: 0.76
# Test Accuracy : 0.75
# ------------------------------
# Combination 396
# colsample_bytree: 0.5, learning_rate: 0.1, max_depth: 10, alpha: 100, n_estimators: 100
# Train Accuracy: 0.78
# Test Accuracy : 0.76
# ------------------------------
# Combination 397
# colsample_bytree: 0.5, learning_rate: 1, max_depth: 3, alpha: 1, n_estimators: 10
# Train Accuracy: 0.78
# Test Accuracy : 0.77
# ------------------------------
# Combination 398
# colsample_bytree: 0.5, learning_rate: 1, max_depth: 3, alpha: 1, n_estimators: 50
# Train Accuracy: 0.81
# Test Accuracy : 0.78
# ------------------------------
# Combination 399
# colsample_bytree: 0.5, learning_rate: 1, max_depth: 3, alpha: 1, n_estimators: 100
# Train Accuracy: 0.83
# Test Accuracy : 0.78
# ------------------------------
# Combination 400
# colsample_bytree: 0.5, learning_rate: 1, max_depth: 3, alpha: 10, n_estimators: 10
# Train Accuracy: 0.77
# Test Accuracy : 0.76
# ------------------------------
# Combination 401
# colsample_bytree: 0.5, learning_rate: 1, max_depth: 3, alpha: 10, n_estimators: 50
# Train Accuracy: 0.80
# Test Accuracy : 0.78
# ------------------------------
# Combination 402
# colsample_bytree: 0.5, learning_rate: 1, max_depth: 3, alpha: 10, n_estimators: 100
# Train Accuracy: 0.81
# Test Accuracy : 0.78
# ------------------------------
# Combination 403
# colsample_bytree: 0.5, learning_rate: 1, max_depth: 3, alpha: 100, n_estimators: 10
# Train Accuracy: 0.76
# Test Accuracy : 0.75
# ------------------------------
# Combination 404
# colsample_bytree: 0.5, learning_rate: 1, max_depth: 3, alpha: 100, n_estimators: 50
# Train Accuracy: 0.77
# Test Accuracy : 0.77
# ------------------------------
# Combination 405
# colsample_bytree: 0.5, learning_rate: 1, max_depth: 3, alpha: 100, n_estimators: 100
# Train Accuracy: 0.77
# Test Accuracy : 0.77
# ------------------------------
# Combination 406
# colsample_bytree: 0.5, learning_rate: 1, max_depth: 5, alpha: 1, n_estimators: 10
# Train Accuracy: 0.80
# Test Accuracy : 0.77
# ------------------------------
# Combination 407
# colsample_bytree: 0.5, learning_rate: 1, max_depth: 5, alpha: 1, n_estimators: 50
# Train Accuracy: 0.87
# Test Accuracy : 0.77
# ------------------------------
# Combination 408
# colsample_bytree: 0.5, learning_rate: 1, max_depth: 5, alpha: 1, n_estimators: 100
# Train Accuracy: 0.93
# Test Accuracy : 0.76
# ------------------------------
# Combination 409
# colsample_bytree: 0.5, learning_rate: 1, max_depth: 5, alpha: 10, n_estimators: 10
# Train Accuracy: 0.79
# Test Accuracy : 0.77
# ------------------------------
# Combination 410
# colsample_bytree: 0.5, learning_rate: 1, max_depth: 5, alpha: 10, n_estimators: 50
# Train Accuracy: 0.83
# Test Accuracy : 0.77
# ------------------------------
# Combination 411
# colsample_bytree: 0.5, learning_rate: 1, max_depth: 5, alpha: 10, n_estimators: 100
# Train Accuracy: 0.86
# Test Accuracy : 0.77
# ------------------------------
# Combination 412
# colsample_bytree: 0.5, learning_rate: 1, max_depth: 5, alpha: 100, n_estimators: 10
# Train Accuracy: 0.77
# Test Accuracy : 0.76
# ------------------------------
# Combination 413
# colsample_bytree: 0.5, learning_rate: 1, max_depth: 5, alpha: 100, n_estimators: 50
# Train Accuracy: 0.78
# Test Accuracy : 0.77
# ------------------------------
# Combination 414
# colsample_bytree: 0.5, learning_rate: 1, max_depth: 5, alpha: 100, n_estimators: 100
# Train Accuracy: 0.78
# Test Accuracy : 0.77
# ------------------------------
# Combination 415
# colsample_bytree: 0.5, learning_rate: 1, max_depth: 8, alpha: 1, n_estimators: 10
# Train Accuracy: 0.86
# Test Accuracy : 0.77
# ------------------------------
# Combination 416
# colsample_bytree: 0.5, learning_rate: 1, max_depth: 8, alpha: 1, n_estimators: 50
# Train Accuracy: 0.99
# Test Accuracy : 0.76
# ------------------------------
# Combination 417
# colsample_bytree: 0.5, learning_rate: 1, max_depth: 8, alpha: 1, n_estimators: 100
# Train Accuracy: 1.00
# Test Accuracy : 0.76
# ------------------------------
# Combination 418
# colsample_bytree: 0.5, learning_rate: 1, max_depth: 8, alpha: 10, n_estimators: 10
# Train Accuracy: 0.81
# Test Accuracy : 0.77
# ------------------------------
# Combination 419
# colsample_bytree: 0.5, learning_rate: 1, max_depth: 8, alpha: 10, n_estimators: 50
# Train Accuracy: 0.89
# Test Accuracy : 0.77
# ------------------------------
# Combination 420
# colsample_bytree: 0.5, learning_rate: 1, max_depth: 8, alpha: 10, n_estimators: 100
# Train Accuracy: 0.93
# Test Accuracy : 0.76
# ------------------------------
# Combination 421
# colsample_bytree: 0.5, learning_rate: 1, max_depth: 8, alpha: 100, n_estimators: 10
# Train Accuracy: 0.77
# Test Accuracy : 0.76
# ------------------------------
# Combination 422
# colsample_bytree: 0.5, learning_rate: 1, max_depth: 8, alpha: 100, n_estimators: 50
# Train Accuracy: 0.78
# Test Accuracy : 0.77
# ------------------------------
# Combination 423
# colsample_bytree: 0.5, learning_rate: 1, max_depth: 8, alpha: 100, n_estimators: 100
# Train Accuracy: 0.78
# Test Accuracy : 0.77
# ------------------------------
# Combination 424
# colsample_bytree: 0.5, learning_rate: 1, max_depth: 10, alpha: 1, n_estimators: 10
# Train Accuracy: 0.92
# Test Accuracy : 0.76
# ------------------------------
# Combination 425
# colsample_bytree: 0.5, learning_rate: 1, max_depth: 10, alpha: 1, n_estimators: 50
# Train Accuracy: 1.00
# Test Accuracy : 0.76
# ------------------------------
# Combination 426
# colsample_bytree: 0.5, learning_rate: 1, max_depth: 10, alpha: 1, n_estimators: 100
# Train Accuracy: 1.00
# Test Accuracy : 0.76
# ------------------------------
# Combination 427
# colsample_bytree: 0.5, learning_rate: 1, max_depth: 10, alpha: 10, n_estimators: 10
# Train Accuracy: 0.83
# Test Accuracy : 0.77
# ------------------------------
# Combination 428
# colsample_bytree: 0.5, learning_rate: 1, max_depth: 10, alpha: 10, n_estimators: 50
# Train Accuracy: 0.91
# Test Accuracy : 0.77
# ------------------------------
# Combination 429
# colsample_bytree: 0.5, learning_rate: 1, max_depth: 10, alpha: 10, n_estimators: 100
# Train Accuracy: 0.95
# Test Accuracy : 0.77
# ------------------------------
# Combination 430
# colsample_bytree: 0.5, learning_rate: 1, max_depth: 10, alpha: 100, n_estimators: 10
# Train Accuracy: 0.77
# Test Accuracy : 0.76
# ------------------------------
# Combination 431
# colsample_bytree: 0.5, learning_rate: 1, max_depth: 10, alpha: 100, n_estimators: 50
# Train Accuracy: 0.78
# Test Accuracy : 0.77
# ------------------------------
# Combination 432
# colsample_bytree: 0.5, learning_rate: 1, max_depth: 10, alpha: 100, n_estimators: 100
# Train Accuracy: 0.78
# Test Accuracy : 0.77
# ------------------------------
# Combination 433
# colsample_bytree: 0.7, learning_rate: 0.001, max_depth: 3, alpha: 1, n_estimators: 10
# Train Accuracy: 0.71
# Test Accuracy : 0.71
# ------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[59], line 31
#      25 y_encoded = label_encoder.fit_transform(y)
#      28 x_train, x_test, y_train, y_test = train_test_split(x, y_encoded, test_size=0.2, random_state=42)
# ---> 31 model.fit(x_train, y_train)
#      35 # Predict on training and testing sets
#      36 y_pred_train = model.predict(x_train)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\xgboost\core.py:729, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     727 for k, arg in zip(sig.parameters, args):
#     728     kwargs[k] = arg
# --> 729 return func(**kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\xgboost\sklearn.py:1683, in XGBClassifier.fit(self, X, y, sample_weight, base_margin, eval_set, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights)
#    1661 model, metric, params, feature_weights = self._configure_fit(
#    1662     xgb_model, params, feature_weights
#    1663 )
#    1664 train_dmatrix, evals = _wrap_evaluation_matrices(
#    1665     missing=self.missing,
#    1666     X=X,
#    (...)
#    1680     feature_types=self.feature_types,
#    1681 )
# -> 1683 self._Booster = train(
#    1684     params,
#    1685     train_dmatrix,
#    1686     self.get_num_boosting_rounds(),
#    1687     evals=evals,
#    1688     early_stopping_rounds=self.early_stopping_rounds,
#    1689     evals_result=evals_result,
#    1690     obj=obj,
#    1691     custom_metric=metric,
#    1692     verbose_eval=verbose,
#    1693     xgb_model=model,
#    1694     callbacks=self.callbacks,
#    1695 )
#    1697 if not callable(self.objective):
#    1698     self.objective = params["objective"]
#
# File ~\AppData\Roaming\Python\Python312\site-packages\xgboost\core.py:729, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     727 for k, arg in zip(sig.parameters, args):
#     728     kwargs[k] = arg
# --> 729 return func(**kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\xgboost\training.py:183, in train(params, dtrain, num_boost_round, evals, obj, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, custom_metric)
#     181 if cb_container.before_iteration(bst, i, dtrain, evals):
#     182     break
# --> 183 bst.update(dtrain, iteration=i, fobj=obj)
#     184 if cb_container.after_iteration(bst, i, dtrain, evals):
#     185     break
#
# File ~\AppData\Roaming\Python\Python312\site-packages\xgboost\core.py:2247, in Booster.update(self, dtrain, iteration, fobj)
#    2243 self._assign_dmatrix_features(dtrain)
#    2245 if fobj is None:
#    2246     _check_call(
# -> 2247         _LIB.XGBoosterUpdateOneIter(
#    2248             self.handle, ctypes.c_int(iteration), dtrain.handle
#    2249         )
#    2250     )
#    2251 else:
#    2252     pred = self.predict(dtrain, output_margin=True, training=True)
#
# KeyboardInterrupt:

# %%
#For unseen data

# # Your program code goes here
# start_time = time.time()


a3 = pd.read_excel("Data/Unseen_Dataset.xlsx")

# %%
cols_in_df = list(df.columns)
cols_in_df.pop(42)
# Out:
# 'Approved_Flag'

# %%
df_unseen = a3[cols_in_df]

# %%
df_unseen['MARITALSTATUS'].unique()
df_unseen['EDUCATION'].unique()
df_unseen['GENDER'].unique()
df_unseen['last_prod_enq2'].unique()
df_unseen['first_prod_enq2'].unique()
# Out:
# array(['PL', 'ConsumerLoan', 'others', 'AL', 'HL', 'CC'], dtype=object)

# %%
# Ordinal feature -- EDUCATION
# SSC : 1
# 12TH : 2
# GRADUTATE : 3
# UNDER GRADUATE : 3
# POST-GRADUATE : 4
# OTHERS : 1
# PROFESSIONAL : 3

# Others has to be verified by the business end user

df_unseen.loc[df_unseen['EDUCATION'] == 'SSC',['EDUCATION']]            = 1
df_unseen.loc[df_unseen['EDUCATION'] == '12TH',['EDUCATION']]           = 2
df_unseen.loc[df_unseen['EDUCATION'] == 'GRADUATE',['EDUCATION']]       = 3
df_unseen.loc[df_unseen['EDUCATION'] == 'UNDER GRADUATE',['EDUCATION']] = 3
df_unseen.loc[df_unseen['EDUCATION'] == 'POST-GRADUATE',['EDUCATION']]  = 4
df_unseen.loc[df_unseen['EDUCATION'] == 'OTHERS',['EDUCATION']]         = 1
df_unseen.loc[df_unseen['EDUCATION'] == 'PROFESSIONAL',['EDUCATION']]   = 3

# %%
df_unseen['EDUCATION'].value_counts()
df_unseen['EDUCATION'] = df_unseen['EDUCATION'].astype(int)
df_unseen.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 42 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   pct_tl_open_L6M            100 non-null    float64
#  1   pct_tl_closed_L6M          100 non-null    float64
#  2   Tot_TL_closed_L12M         100 non-null    int64
#  3   pct_tl_closed_L12M         100 non-null    float64
#  4   Tot_Missed_Pmnt            100 non-null    int64
#  5   CC_TL                      100 non-null    int64
#  6   Home_TL                    100 non-null    int64
#  7   PL_TL                      100 non-null    int64
#  8   Secured_TL                 100 non-null    int64
#  9   Unsecured_TL               100 non-null    int64
#  10  Other_TL                   100 non-null    int64
#  11  Age_Oldest_TL              100 non-null    int64
#  12  Age_Newest_TL              100 non-null    int64
#  13  time_since_recent_payment  100 non-null    int64
#  14  max_recent_level_of_deliq  100 non-null    int64
#  15  num_deliq_6_12mts          100 non-null    int64
#  16  num_times_60p_dpd          100 non-null    int64
#  17  num_std_12mts              100 non-null    int64
#  18  num_sub                    100 non-null    int64
#  19  num_sub_6mts               100 non-null    int64
#  20  num_sub_12mts              100 non-null    int64
#  21  num_dbt                    100 non-null    int64
#  22  num_dbt_12mts              100 non-null    int64
#  23  num_lss                    100 non-null    int64
#  24  recent_level_of_deliq      100 non-null    int64
#  25  CC_enq_L12m                100 non-null    int64
#  26  PL_enq_L12m                100 non-null    int64
#  27  time_since_recent_enq      100 non-null    int64
#  28  enq_L3m                    100 non-null    int64
#  29  NETMONTHLYINCOME           100 non-null    int64
#  30  Time_With_Curr_Empr        100 non-null    int64
#  31  CC_Flag                    100 non-null    int64
#  32  PL_Flag                    100 non-null    int64
#  33  pct_PL_enq_L6m_of_ever     100 non-null    float64
#  34  pct_CC_enq_L6m_of_ever     100 non-null    float64
#  35  HL_Flag                    100 non-null    int64
#  36  GL_Flag                    100 non-null    int64
#  37  MARITALSTATUS              100 non-null    object
#  38  EDUCATION                  100 non-null    int64
#  39  GENDER                     100 non-null    object
#  40  last_prod_enq2             100 non-null    object
#  41  first_prod_enq2            100 non-null    object
# dtypes: float64(5), int64(33), object(4)
# memory usage: 32.9+ KB

# %%
df_encoded_unseen = pd.get_dummies(df_unseen, columns=['MARITALSTATUS','GENDER', 'last_prod_enq2' ,'first_prod_enq2'])


df_encoded_unseen.info()
k = df_encoded_unseen.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 54 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   pct_tl_open_L6M               100 non-null    float64
#  1   pct_tl_closed_L6M             100 non-null    float64
#  2   Tot_TL_closed_L12M            100 non-null    int64
#  3   pct_tl_closed_L12M            100 non-null    float64
#  4   Tot_Missed_Pmnt               100 non-null    int64
#  5   CC_TL                         100 non-null    int64
#  6   Home_TL                       100 non-null    int64
#  7   PL_TL                         100 non-null    int64
#  8   Secured_TL                    100 non-null    int64
#  9   Unsecured_TL                  100 non-null    int64
#  10  Other_TL                      100 non-null    int64
#  11  Age_Oldest_TL                 100 non-null    int64
#  12  Age_Newest_TL                 100 non-null    int64
#  13  time_since_recent_payment     100 non-null    int64
#  14  max_recent_level_of_deliq     100 non-null    int64
#  15  num_deliq_6_12mts             100 non-null    int64
#  16  num_times_60p_dpd             100 non-null    int64
#  17  num_std_12mts                 100 non-null    int64
#  18  num_sub                       100 non-null    int64
#  19  num_sub_6mts                  100 non-null    int64
#  20  num_sub_12mts                 100 non-null    int64
#  21  num_dbt                       100 non-null    int64
#  22  num_dbt_12mts                 100 non-null    int64
#  23  num_lss                       100 non-null    int64
#  24  recent_level_of_deliq         100 non-null    int64
#  25  CC_enq_L12m                   100 non-null    int64
#  26  PL_enq_L12m                   100 non-null    int64
#  27  time_since_recent_enq         100 non-null    int64
#  28  enq_L3m                       100 non-null    int64
#  29  NETMONTHLYINCOME              100 non-null    int64
#  30  Time_With_Curr_Empr           100 non-null    int64
#  31  CC_Flag                       100 non-null    int64
#  32  PL_Flag                       100 non-null    int64
#  33  pct_PL_enq_L6m_of_ever        100 non-null    float64
#  34  pct_CC_enq_L6m_of_ever        100 non-null    float64
#  35  HL_Flag                       100 non-null    int64
#  36  GL_Flag                       100 non-null    int64
#  37  EDUCATION                     100 non-null    int64
#  38  MARITALSTATUS_Married         100 non-null    bool
#  39  MARITALSTATUS_Single          100 non-null    bool
#  40  GENDER_F                      100 non-null    bool
#  41  GENDER_M                      100 non-null    bool
#  42  last_prod_enq2_AL             100 non-null    bool
#  43  last_prod_enq2_CC             100 non-null    bool
#  44  last_prod_enq2_ConsumerLoan   100 non-null    bool
#  45  last_prod_enq2_HL             100 non-null    bool
#  46  last_prod_enq2_PL             100 non-null    bool
#  47  last_prod_enq2_others         100 non-null    bool
#  48  first_prod_enq2_AL            100 non-null    bool
#  49  first_prod_enq2_CC            100 non-null    bool
#  50  first_prod_enq2_ConsumerLoan  100 non-null    bool
#  51  first_prod_enq2_HL            100 non-null    bool
#  52  first_prod_enq2_PL            100 non-null    bool
#  53  first_prod_enq2_others        100 non-null    bool
# dtypes: bool(16), float64(5), int64(33)
# memory usage: 31.4 KB

# %%
model = xgb.XGBClassifier(objective='multi:softmax',
                                     num_class=4,
                                     colsample_bytree=0.9,
                                     learning_rate=1,
                                     max_depth=3,
                                     alpha=10,
                                     n_estimators=100)

# %%
model.fit(x_train, y_train)
# Out:
# XGBClassifier(alpha=10, base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.9, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=1, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=3,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=100,
#               n_jobs=None, ...)

# %%
y_pred_unseen = model.predict(df_encoded_unseen)

# %%
a3['Target_variable'] = y_pred_unseen
